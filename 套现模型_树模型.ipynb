# %%
import datetime
import time
import pandas as pd
import numpy as np
from collections import Counter, defaultdict
from functools import reduce
from tqdm.notebook import tqdm
import warnings
import json
import re
import math
# 模型训练及测试
from sklearn.preprocessing import OneHotEncoder
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
import pydotplus
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
import joblib
from IPython.display import Image

# from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
# from imblearn.under_sampling import RandomUnderSampler, ClusterCentroids, NearMiss
# from imblearn.combine import SMOTEENN, SMOTETomek

# 画图
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['font.sans-serif']=['SimHei'] 
plt.rcParams['font.family']='sans-serif'

from dtreeviz.trees import dtreeviz, explain_prediction_path

warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 5000)

# %%
def get_bin(sample_df_raw, column):
    b = sorted(set([-np.inf
#                     , np.quantile(sample_df_raw[column], 0.1)
                    , np.quantile(sample_df_raw[column], 0.2)
#                     , np.quantile(sample_df_raw[column], 0.3)
                    , np.quantile(sample_df_raw[column], 0.4)
#                     , np.quantile(sample_df_raw[column], 0.5)
                    , np.quantile(sample_df_raw[column], 0.6)
#                     , np.quantile(sample_df_raw[column], 0.7)
                    , np.quantile(sample_df_raw[column], 0.8)
#                     , np.quantile(sample_df_raw[column], 0.9)
                    , np.inf]))
    return pd.cut(sample_df_raw[column], b)


def get_metrics(sample_df, column, y, psi_split):
    tmp_df = sample_df[['下单时间', column, y]].copy(deep=True)
    tmp_df = tmp_df[tmp_df[column]!=-9999].reset_index(drop=True)
    
    total = tmp_df.shape[0]
    bad = tmp_df[tmp_df[y]==1].shape[0]
    good = tmp_df[tmp_df[y]==0].shape[0]
    badratio = bad/total
    
    
    tmp_df[column+'_bin'] = get_bin(sample_df, column)
    column_df = tmp_df.groupby(column+'_bin')[y].agg([np.size, np.sum]).reset_index().dropna(axis=0, how='any')
    column_df.columns = ['分箱', '个数', '坏样本']
    column_df['特征'] = column
    column_df['整体个数'] = total
    column_df['整体坏样本'] = bad
    column_df['整体好样本'] = good
    column_df['整体badratio'] = badratio
    column_df['好样本'] = column_df['个数'] - column_df['坏样本']
    column_df['badratio'] = column_df['坏样本']/column_df['个数']
    column_df['累计badrate'] = column_df['坏样本'].cumsum()/bad
    column_df['累计goodrate'] = column_df['好样本'].cumsum()/good
    column_df['KS分量'] = abs(column_df['累计badrate'] - column_df['累计goodrate'])
    column_df['KS'] = max(column_df['KS分量'])
    column_df['WOE'] = np.log((column_df['好样本']/good)/(column_df['坏样本']/bad))
    column_df['IV'] = sum((column_df['好样本']/good - column_df['坏样本']/bad)*column_df['WOE'])
#     column_df['lift'] = column_df['badratio']/badratio
#     column_df['minlift'] = min(column_df['lift'])
#     column_df['maxlift'] = max(column_df['lift'])
#     column_df['上累计lift'] = (column_df['坏样本'].cumsum()/column_df['个数'].cumsum())/badratio
#     column_df['下累计lift'] = ((bad-column_df['坏样本'].cumsum())/(total-column_df['个数'].cumsum()))/badratio
#     column_df['max上累计lift'] = max(column_df['上累计lift'])
#     column_df['max下累计lift'] = max(column_df['下累计lift'])
    
    Actual = tmp_df[tmp_df['下单时间']>psi_split]
    Expect = tmp_df[tmp_df['下单时间']<=psi_split]
    ashape = Actual.shape[0]
    eshape = Expect.shape[0]
    apsi_df = Actual.groupby(column+'_bin')[y].agg(np.size).reset_index()
    epsi_df = Expect.groupby(column+'_bin')[y].agg(np.size).reset_index()
    apsi_df.columns = ['分箱', 'a个数']
    epsi_df.columns = ['分箱', 'e个数']
    apsi_df['a占比'] = apsi_df['a个数']/ashape
    epsi_df['e占比'] = epsi_df['e个数']/eshape
    apsi_df['a占比'] = apsi_df['a占比'].fillna(0)
    epsi_df['e占比'] = epsi_df['e占比'].fillna(0)
    psi_df = apsi_df.merge(epsi_df, on='分箱', how='left')
    psi_df['PSI分量'] = (psi_df['a占比']-psi_df['e占比'])*np.log(psi_df['a占比']/psi_df['e占比'])
    psi_df['PSI分量'] = psi_df['PSI分量'].replace(np.inf, 0)
    column_df = column_df.merge(psi_df, on='分箱', how='left')
    column_df['PSI'] = sum(column_df['PSI分量'])
    

    floor = np.quantile(tmp_df[column], 0.05)
    roof = np.quantile(tmp_df[column], 0.95)
    tmp_cut = set(tmp_df[(tmp_df[column]>=floor)&(tmp_df[column]<=roof)][column])

    # bestlift
    maxlift = 0
    minlift = 1
    maxliftcut = floor
    minliftcut = floor

    for c in tmp_cut:
        tmp_df[column+'_bin2'] = pd.cut(tmp_df[column], [-np.inf, c, np.inf])
        tmp_column_df = tmp_df.groupby(column+'_bin2')[y].agg([np.size, np.sum]).reset_index().dropna(axis=0, how='any')
        tmp_column_df.columns = ['分箱', '个数', '坏样本']
        tmp_column_df['特征'] = column
        tmp_column_df['badratio'] = tmp_column_df['坏样本']/tmp_column_df['个数']
        tmpmaxlift = max(tmp_column_df['badratio'])/badratio
        tmpminlift = min(tmp_column_df['badratio'])/badratio
        
        if maxlift < tmpmaxlift:
            maxlift = tmpmaxlift
            maxliftcut = c
        if minlift > tmpminlift:
            minlift = tmpminlift
            minliftcut = c
            
    column_df['maxlift'] = maxlift
    column_df['minlift'] = minlift
    column_df['maxliftcut'] = maxliftcut
    column_df['minliftcut'] = minliftcut
    
    # bestks
    bestks = 0
    bestkscut = floor

    for c in tmp_cut:
        bad_sample = sum(tmp_df[tmp_df[column]<=c][y])
        good_sample = tmp_df[tmp_df[column]<=c][y].shape[0] - bad_sample
        tmpbestks = abs(bad_sample/bad - good_sample/good)
        
        if bestks < tmpbestks:
            bestks = tmpbestks
            bestkscut = c
            
    column_df['bestks'] = bestks
    column_df['bestkscut'] = bestkscut
    
    return column_df[[
        '特征'
        ,'分箱'
        ,'整体个数'
        ,'整体坏样本'
        ,'整体好样本'
        ,'整体badratio'
        ,'个数'
        ,'坏样本'
        ,'好样本'
        ,'badratio'
        ,'累计badrate'
        ,'累计goodrate'
        ,'KS分量'
        ,'KS'
        ,'WOE'
        ,'IV'
#         ,'lift'
        ,'minlift'
        ,'maxlift'
        ,'minliftcut'
        ,'maxliftcut'
        ,'bestks'
        ,'bestkscut'
#         ,'上累计lift'
#         ,'下累计lift'
#         ,'max上累计lift'
#         ,'max下累计lift'
        ,'a占比'
        ,'e占比'
        ,'PSI分量'
        ,'PSI'
]]


def get_ks(df):
    tmp_df = df.copy(deep=True)
    
    total = tmp_df.shape[0]
    bad = tmp_df[tmp_df['t']==1].shape[0]
    good = tmp_df[tmp_df['t']==0].shape[0]
    badratio = bad/total
    
    column_df = tmp_df.groupby('特征')['t'].agg([np.size, np.sum]).reset_index().dropna(axis=0, how='any')
    column_df.columns = ['分箱', '个数', '坏样本']
    column_df = column_df.sort_values(by='分箱', ascending=False).reset_index(drop=True)
    column_df['整体个数'] = total
    column_df['整体坏样本'] = bad
    column_df['整体好样本'] = good
    column_df['整体badratio'] = badratio
    column_df['好样本'] = column_df['个数'] - column_df['坏样本']
    column_df['badratio'] = column_df['坏样本']/column_df['个数']
    column_df['累计badrate'] = column_df['坏样本'].cumsum()/bad
    column_df['累计goodrate'] = column_df['好样本'].cumsum()/good
    column_df['KS分量'] = abs(column_df['累计badrate'] - column_df['累计goodrate'])
    column_df['KS'] = max(column_df['KS分量'])
    column_df['累计lift'] = (column_df['坏样本'].cumsum()/column_df['个数'].cumsum())/badratio
    
    return column_df[['分箱','个数','坏样本','好样本','累计badrate','累计goodrate','累计lift','KS分量','KS','badratio']]


def coverage_calc(df, colnames=None, mi_values=[], mi_dict={}, bar=False):
    result = []
    cnt = []
    if not colnames:
        colnames = df.columns.tolist()
    for name in colnames:
        mi_item_total = df[name].isnull().sum() + df[name].isin(mi_values).sum()
        mi_perc = mi_item_total / len(df[name])*100
        name_coverage = 100 - mi_perc
#         name_coverage = "%.2f%%" % name_coverage
        cnt.append(df.shape[0] - mi_item_total)
        result.append(name_coverage)

    if bar:
        return pd.DataFrame({"变量": colnames, "非空个数": cnt, "占比": result}).style.bar(subset=["占比"])
    else:
        return pd.DataFrame({"变量": colnames, "非空个数": cnt, "占比": result})


def datediff(t1, t2):
    try:
        _t1 = datetime.datetime.strptime(str(t1),"%Y-%m-%d %H:%M:%S")
        _t2 = datetime.datetime.strptime(str(t2),"%Y-%m-%d %H:%M:%S")
    except:
        return -9999
    return (_t1 - _t2).days


def concentration(df):
    tt = target.replace('_ind','')
    amo =np.sum(df[tt+'amo'])
    amosum = np.sum(df[tt+'amosum'])
    return amo/amosum

# %%
#定义节点的属性
class decisionnode:
    def __init__(self,col = None,value = None, results = None, tb = None,fb = None):
        self.col = col   # col是待检验的判断条件所对应的列索引值
        self.value = value # value对应于为了使结果为True，当前列必须匹配的值
        self.results = results #保存的是针对当前分支的结果，它是一个字典
        self.tb = tb ## desision node,对应于结果为true时，树上相对于当前节点的子树上的节点
        self.fb = fb ## desision node,对应于结果为true时，树上相对于当前节点的子树上的节点


#在某一列上对数据集进行拆分。可应用于数值型或因子型变量
def divideset(df,column,value):
    #定义一个函数，判断当前数据行属于第一组还是第二组
    split_function = None
    if isinstance(value,int) or isinstance(value,float):
#          and len(dict(Counter(df[column])))>2
        set1 = df[df[column]>=value].reset_index(drop=True)
        set2 = df[~(df[column]>=value)].reset_index(drop=True)
    else:
        set1 = df[df[column]==value].reset_index(drop=True)
        set2 = df[~(df[column]==value)].reset_index(drop=True)
    return(set1,set2)


# 以递归方式构造树

def buildtree(df, selectedcol=None, max_depth=np.inf, min_samples_leaf=1):
    if len(df)==0 : return decisionnode()
    current_score = concentration(df)
    
    # 定义一些变量以记录最佳拆分条件
    best_gain = 1
    best_criteria = None
    best_sets = None
    
    for col in selectedcol:

        #根据这一列中的每个值，尝试对数据集进行拆分
        for value in set(df[col]):
            (set1,set2) = divideset(df,col,value)
            
            # lift
            gain = max(concentration(set1), concentration(set2))/current_score
            if gain>best_gain and len(set1)>=min_samples_leaf and len(set2)>=min_samples_leaf:
                tmp_res = dict(Counter(df[target]))
                tmp_res['con'] = round(current_score, 4)
                best_gain = gain
                best_res = tmp_res
                best_criteria = (col,value)
                best_sets = (set1,set2)
                
    #创建子分支
    if best_gain>1 and max_depth>0:
        trueBranch = buildtree(best_sets[0], [x for x in selectedcol if x!=best_criteria[0]], max_depth-1, min_samples_leaf)  #递归调用
        falseBranch = buildtree(best_sets[1], [x for x in selectedcol if x!=best_criteria[0]], max_depth-1, min_samples_leaf)
        return decisionnode(col = best_criteria[0],value = best_criteria[1], results=best_res,
                            tb = trueBranch,fb = falseBranch)
    else:
        end_res = dict(Counter(df[target]))
        end_res['con'] = round(current_score, 4)
        return decisionnode(results = end_res)
    

# 决策树的显示
def printtree(tree,indent = ''):
    # 是否是叶节点
    if tree.tb==None:
        print(str(tree.results))
    else:
        # 打印判断条件
        if isinstance(tree.value,int) or isinstance(tree.value,float):
            print(str(tree.results)+"\n"+indent+str(tree.col)+">="+str(tree.value)+"?")
        else:
            print(str(tree.results)+"\n"+indent+str(tree.col)+":"+str(tree.value)+"?")
        #打印分支
        print(indent+"T->", end="")
        printtree(tree.tb,"\t"+indent)
        print(indent+"F->", end="")
        printtree(tree.fb,"\t"+indent)
        


# 对新的观测数据进行分类


def classify(observation,tree, p=None):
    if not tree.col:
        return tree.results
    else:
        v = observation[tree.col]
        branch = None
        if isinstance(v,int) or isinstance(v,float):
            if v>= tree.value: 
                branch = tree.tb
                if p: print(tree.col+" >= "+str(tree.value))
            else: 
                branch = tree.fb
                if p: print(tree.col+" < "+str(tree.value))
        else:
            if v==tree.value:
                branch = tree.tb
                if p: print(tree.col+" 等于 "+str(tree.value))
            else: 
                branch = tree.fb
                if p: print(tree.col+" 不等于 "+str(tree.value))
        return classify(observation,branch, p)

# %% [markdown]
# # 导入

# %%
# 导入数据
tmp_repayinfo_shl = pd.read_csv('./raw_data/tmp_fraud_shl_20220728.txt')

# %%
tmp_repayinfo_shl.shape
# Out:
# (529495, 397)

# %% [markdown]
# # 调整

# %%
# 缺失值与标签
repayinfo = tmp_repayinfo_shl.copy(deep=True)
repayinfo.replace('\\N', np.nan, inplace=True)
repayinfo.replace('N', np.nan, inplace=True)
repayinfo['fpd3amo'] = repayinfo['fpd3amo'].astype('float64')
repayinfo['fpd7amo'] = repayinfo['fpd7amo'].astype('float64')
repayinfo['fpd15amo'] = repayinfo['fpd15amo'].astype('float64')
repayinfo['mob3_dpd15amo'] = repayinfo['mob3_dpd15amo'].astype('float64')
repayinfo['fpd3amosum'] = repayinfo['fpd3amosum'].astype('float64')
repayinfo['fpd7amosum'] = repayinfo['fpd7amosum'].astype('float64')
repayinfo['fpd15amosum'] = repayinfo['fpd15amosum'].astype('float64')
repayinfo['mob3_dpd15amosum'] = repayinfo['mob3_dpd15amosum'].astype('float64')

# %%
# 逾期标签
repayinfo['fd3_ind'] = repayinfo['fd3_ind'].astype('float64')
repayinfo['fd7_ind'] = repayinfo['fd7_ind'].astype('float64')
repayinfo['fd15_ind'] = repayinfo['fd15_ind'].astype('float64')
repayinfo['mob3_dd15_ind'] = repayinfo['mob3_dd15_ind'].astype('float64')
repayinfo['fpd3_ind'] = repayinfo['fpd3_ind'].astype('float64')
repayinfo['fpd7_ind'] = repayinfo['fpd7_ind'].astype('float64')
repayinfo['fpd15_ind'] = repayinfo['fpd15_ind'].astype('float64')
repayinfo['mob3_dpd15_ind'] = repayinfo['mob3_dpd15_ind'].astype('float64')

# %%
ftr_ord = [
#  '客群',
#  '新户类型',
#  '检测省份',
#  '手机归属地省份',
#  '身份证归属地省份',
#  '收货省份',
#  '品类',
 '百行非循环借贷当前最严重逾期状态',
 '百行循环借贷当前最严重逾期状态',
 '百行循环借贷历史最严重逾期状态_过去1080天',
 '数微近3月查询次数贷款审批',
 '数微近3月查询次数信用卡审批',
 '数微近6月查询次数贷款审批',
 '数微近6月查询次数信用卡审批',
 '数微近3月贷记卡最大逾期期数',
 '数微近1月内的查询次数_贷款审批',
 '数微近1月内的查询次数_信用卡审批',
 '数微近1月内的查询次数_本人查询',
 '数微贷记卡账户当前总额度使用率',
 '数微最近新发放的3张贷记卡平均额度',
 '数微贷记卡账户近6月平均额度总的使用率',
 '数微贷记卡单家机构最高授信额',
 '数微贷记卡单家机构最低授信额',
 '数微贷记卡授信总额',
 '数微贷记卡最近6个月平均使用额度',
 '数微循环贷账户6月平均应还款',
 '数微非循环贷账户6月平均应还款',
 '数微全账户使用率_已用额度除以授信总额',
 '数微全账户近24月逾期期数大于或等于1的次数',
 '数微循环贷账户授信总额',
 '数微学历',
 '数微华北征信分',
]

ftr_num = [
 '留存时间',
 '年龄',
 '百行循环借贷累计逾期次数',
 '百融按身份证号查询_近12个月申请其他的次数',
 '百融按手机号查询_近6个月在非银机构最大月申请次数',
 '百融按身份证号查询_近3个月在非银机构申请次数',
 '百融近12个月_通过手机号查询_在银行_区域银行机构申请次数',
 '百融近12个月_通过手机号查询_在银行_区域银行机构申请机构数',
 '百融近3个月_通过手机号查询_在银行_区域银行机构申请机构数',
 '百融按身份证号查询_近6个月在非银机构申请次数',
 '百融近6个月_通过手机号查询_在银行_区域银行机构申请机构数',
 '同盾近7天查询次数',
 '同盾近15天查询次数',
 '同盾近30天查询次数',
 '同盾近90天查询次数',
 '同盾近180天查询次数',
 '同盾近360天查询次数',
 '同盾近540天查询次数',
 '同盾近720天查询次数',
 '同盾近1800天查询次数',
 '多次下单_3天内购买多个高套现风险类别商品',
 '多次下单_7天内购买多个高套现风险类别商品',
 '多次下单_15天内购买多个高套现风险类别商品',
 '多次下单_30天内购买多个高套现风险类别商品',
 '多次下单_90天内购买多个高套现风险类别商品',
 '多次下单_180天内购买多个高套现风险类别商品',
 '多次下单_3天内购买多个易套现类别商品',
 '多次下单_7天内购买多个易套现类别商品',
 '多次下单_15天内购买多个易套现类别商品',
 '多次下单_30天内购买多个易套现类别商品',
 '多次下单_90天内购买多个易套现类别商品',
 '多次下单_180天内购买多个易套现类别商品',
 '多次下单_3天内多次借款',
 '多次下单_7天内多次借款',
 '多次下单_15天内多次借款',
 '多次下单_30天内多次借款',
 '多次下单_90天内多次借款',
 '多次下单_180天内多次借款',
 '收货行为_检测城市和手机归属地城市不一致',
 '收货行为_检测城市和身份证归属地城市不一致',
 '收货行为_检测城市和收货城市不一致',
 '收货行为_手机归属地城市和身份证归属地城市不一致',
 '收货行为_手机归属地城市和收货城市不一致',
 '收货行为_身份证归属地城市和收货城市不一致',
 '收货行为_检测省份和手机归属地省份不一致',
 '收货行为_检测省份和身份证归属地省份不一致',
 '收货行为_检测省份和收货省份不一致',
 '收货行为_手机归属地省份和身份证归属地省份不一致',
 '收货行为_手机归属地省份和收货省份不一致',
 '收货行为_身份证归属地省份和收货省份不一致',
 '手机号码_注册手机和收货手机不一致',
 '手机号码_收货手机和紧急联系人不一致',
 '收货行为_3天内使用多个不同城市地址下单商品',
 '收货行为_7天内使用多个不同城市地址下单商品',
 '收货行为_15天内使用多个不同城市地址下单商品',
 '收货行为_30天内使用多个不同城市地址下单商品',
 '收货行为_90天内使用多个不同城市地址下单商品',
 '收货行为_180天内使用多个不同城市地址下单商品',
 '收货行为_3天内使用多个不同省份地址下单商品',
 '收货行为_7天内使用多个不同省份地址下单商品',
 '收货行为_15天内使用多个不同省份地址下单商品',
 '收货行为_30天内使用多个不同省份地址下单商品',
 '收货行为_90天内使用多个不同省份地址下单商品',
 '收货行为_180天内使用多个不同省份地址下单商品',
 '收货行为_3天内使用多个不同收货手机下单',
 '收货行为_7天内使用多个不同收货手机下单',
 '收货行为_15天内使用多个不同收货手机下单',
 '收货行为_30天内使用多个不同收货手机下单',
 '收货行为_90天内使用多个不同收货手机下单',
 '收货行为_180天内使用多个不同收货手机下单',
 '手机号码_3天内收货手机关联多人下单',
 '手机号码_7天内收货手机关联多人下单',
 '手机号码_15天内收货手机关联多人下单',
 '手机号码_30天内收货手机关联多人下单',
 '手机号码_90天内收货手机关联多人下单',
 '手机号码_180天内收货手机关联多人下单',
 '手机号码_3天内收货手机关联多人高风险套现下单',
 '手机号码_7天内收货手机关联多人高风险套现下单',
 '手机号码_15天内收货手机关联多人高风险套现下单',
 '手机号码_30天内收货手机关联多人高风险套现下单',
 '手机号码_90天内收货手机关联多人高风险套现下单',
 '手机号码_180天内收货手机关联多人高风险套现下单',
 '手机号码_3天内收货手机关联多人易套现下单',
 '手机号码_7天内收货手机关联多人易套现下单',
 '手机号码_15天内收货手机关联多人易套现下单',
 '手机号码_30天内收货手机关联多人易套现下单',
 '手机号码_90天内收货手机关联多人易套现下单',
 '手机号码_180天内收货手机关联多人易套现下单',
 '手机号码_3天内收货手机关联多人借款下单',
 '手机号码_7天内收货手机关联多人借款下单',
 '手机号码_15天内收货手机关联多人借款下单',
 '手机号码_30天内收货手机关联多人借款下单',
 '手机号码_90天内收货手机关联多人借款下单',
 '手机号码_180天内收货手机关联多人借款下单',
 '手机号码_3天内紧急联系人关联多人下单',
 '手机号码_7天内紧急联系人关联多人下单',
 '手机号码_15天内紧急联系人关联多人下单',
 '手机号码_30天内紧急联系人关联多人下单',
 '手机号码_90天内紧急联系人关联多人下单',
 '手机号码_180天内紧急联系人关联多人下单',
 '手机号码_3天内紧急联系人关联多人高风险套现下单',
 '手机号码_7天内紧急联系人关联多人高风险套现下单',
 '手机号码_15天内紧急联系人关联多人高风险套现下单',
 '手机号码_30天内紧急联系人关联多人高风险套现下单',
 '手机号码_90天内紧急联系人关联多人高风险套现下单',
 '手机号码_180天内紧急联系人关联多人高风险套现下单',
 '手机号码_3天内紧急联系人关联多人易套现下单',
 '手机号码_7天内紧急联系人关联多人易套现下单',
 '手机号码_15天内紧急联系人关联多人易套现下单',
 '手机号码_30天内紧急联系人关联多人易套现下单',
 '手机号码_90天内紧急联系人关联多人易套现下单',
 '手机号码_180天内紧急联系人关联多人易套现下单',
 '手机号码_3天内紧急联系人关联多人借款下单',
 '手机号码_7天内紧急联系人关联多人借款下单',
 '手机号码_15天内紧急联系人关联多人借款下单',
 '手机号码_30天内紧急联系人关联多人借款下单',
 '手机号码_90天内紧急联系人关联多人借款下单',
 '手机号码_180天内紧急联系人关联多人借款下单',
 '手机号码_3天内收货手机以注册手机下单',
 '手机号码_7天内收货手机以注册手机下单',
 '手机号码_15天内收货手机以注册手机下单',
 '手机号码_30天内收货手机以注册手机下单',
 '手机号码_90天内收货手机以注册手机下单',
 '手机号码_180天内收货手机以注册手机下单',
 '手机号码_3天内收货手机以注册手机下单高风险套现',
 '手机号码_7天内收货手机以注册手机下单高风险套现',
 '手机号码_15天内收货手机以注册手机下单高风险套现',
 '手机号码_30天内收货手机以注册手机下单高风险套现',
 '手机号码_90天内收货手机以注册手机下单高风险套现',
 '手机号码_180天内收货手机以注册手机下单高风险套现',
 '手机号码_3天内收货手机以注册手机下单易套现',
 '手机号码_7天内收货手机以注册手机下单易套现',
 '手机号码_15天内收货手机以注册手机下单易套现',
 '手机号码_30天内收货手机以注册手机下单易套现',
 '手机号码_90天内收货手机以注册手机下单易套现',
 '手机号码_180天内收货手机以注册手机下单易套现',
 '手机号码_3天内收货手机以注册手机下单借款',
 '手机号码_7天内收货手机以注册手机下单借款',
 '手机号码_15天内收货手机以注册手机下单借款',
 '手机号码_30天内收货手机以注册手机下单借款',
 '手机号码_90天内收货手机以注册手机下单借款',
 '手机号码_180天内收货手机以注册手机下单借款',
 '手机号码_3天内紧急联系人以注册手机下单',
 '手机号码_7天内紧急联系人以注册手机下单',
 '手机号码_15天内紧急联系人以注册手机下单',
 '手机号码_30天内紧急联系人以注册手机下单',
 '手机号码_90天内紧急联系人以注册手机下单',
 '手机号码_180天内紧急联系人以注册手机下单',
 '手机号码_3天内紧急联系人以注册手机下单高风险套现',
 '手机号码_7天内紧急联系人以注册手机下单高风险套现',
 '手机号码_15天内紧急联系人以注册手机下单高风险套现',
 '手机号码_30天内紧急联系人以注册手机下单高风险套现',
 '手机号码_90天内紧急联系人以注册手机下单高风险套现',
 '手机号码_180天内紧急联系人以注册手机下单高风险套现',
 '手机号码_3天内紧急联系人以注册手机下单易套现',
 '手机号码_7天内紧急联系人以注册手机下单易套现',
 '手机号码_15天内紧急联系人以注册手机下单易套现',
 '手机号码_30天内紧急联系人以注册手机下单易套现',
 '手机号码_90天内紧急联系人以注册手机下单易套现',
 '手机号码_180天内紧急联系人以注册手机下单易套现',
 '手机号码_3天内紧急联系人以注册手机下单借款',
 '手机号码_7天内紧急联系人以注册手机下单借款',
 '手机号码_15天内紧急联系人以注册手机下单借款',
 '手机号码_30天内紧急联系人以注册手机下单借款',
 '手机号码_90天内紧急联系人以注册手机下单借款',
 '手机号码_180天内紧急联系人以注册手机下单借款',
 '关联地址_3天内收货地址76米内被多个新户使用',
 '关联地址_7天内收货地址76米内被多个新户使用',
 '关联地址_15天内收货地址76米内被多个新户使用',
 '关联地址_30天内收货地址76米内被多个新户使用',
 '关联地址_90天内收货地址76米内被多个新户使用',
 '关联地址_180天内收货地址76米内被多个新户使用',
 '关联地址_3天内收货地址76米内被多个下单高套现风险新户使用',
 '关联地址_7天内收货地址76米内被多个下单高套现风险新户使用',
 '关联地址_15天内收货地址76米内被多个下单高套现风险新户使用',
 '关联地址_30天内收货地址76米内被多个下单高套现风险新户使用',
 '关联地址_90天内收货地址76米内被多个下单高套现风险新户使用',
 '关联地址_180天内收货地址76米内被多个下单高套现风险新户使用',
 '关联地址_3天内收货地址76米内被多个下单易套现新户使用',
 '关联地址_7天内收货地址76米内被多个下单易套现新户使用',
 '关联地址_15天内收货地址76米内被多个下单易套现新户使用',
 '关联地址_30天内收货地址76米内被多个下单易套现新户使用',
 '关联地址_90天内收货地址76米内被多个下单易套现新户使用',
 '关联地址_180天内收货地址76米内被多个下单易套现新户使用',
 '关联地址_3天内收货地址610米内被多个新户使用',
 '关联地址_7天内收货地址610米内被多个新户使用',
 '关联地址_15天内收货地址610米内被多个新户使用',
 '关联地址_30天内收货地址610米内被多个新户使用',
 '关联地址_90天内收货地址610米内被多个新户使用',
 '关联地址_180天内收货地址610米内被多个新户使用',
 '关联地址_3天内收货地址610米内被多个下单高套现风险新户使用',
 '关联地址_7天内收货地址610米内被多个下单高套现风险新户使用',
 '关联地址_15天内收货地址610米内被多个下单高套现风险新户使用',
 '关联地址_30天内收货地址610米内被多个下单高套现风险新户使用',
 '关联地址_90天内收货地址610米内被多个下单高套现风险新户使用',
 '关联地址_180天内收货地址610米内被多个下单高套现风险新户使用',
 '关联地址_3天内收货地址610米内被多个下单易套现新户使用',
 '关联地址_7天内收货地址610米内被多个下单易套现新户使用',
 '关联地址_15天内收货地址610米内被多个下单易套现新户使用',
 '关联地址_30天内收货地址610米内被多个下单易套现新户使用',
 '关联地址_90天内收货地址610米内被多个下单易套现新户使用',
 '关联地址_180天内收货地址610米内被多个下单易套现新户使用',
 '关联地址_收货地址76米内3天内注册新户数',
 '关联地址_收货地址76米内7天内注册新户数',
 '关联地址_收货地址76米内15天内注册新户数',
 '关联地址_收货地址76米内30天内注册新户数',
 '关联地址_收货地址76米内90天内注册新户数',
 '关联地址_收货地址76米内180天内注册新户数',
 '关联地址_收货地址610米内3天内注册新户数',
 '关联地址_收货地址610米内7天内注册新户数',
 '关联地址_收货地址610米内15天内注册新户数',
 '关联地址_收货地址610米内30天内注册新户数',
 '关联地址_收货地址610米内90天内注册新户数',
 '关联地址_收货地址610米内180天内注册新户数',
 '下单行为_3天内虚拟订单取消个数',
 '下单行为_7天内虚拟订单取消个数',
 '下单行为_15天内虚拟订单取消个数',
 '下单行为_30天内虚拟订单取消个数',
 '下单行为_90天内虚拟订单取消个数',
 '下单行为_180天内虚拟订单取消个数',
 '交易行为_3天内多次下单相同商品个数',
 '交易行为_7天内多次下单相同商品个数',
 '交易行为_15天内多次下单相同商品个数',
 '交易行为_30天内多次下单相同商品个数',
 '交易行为_90天内多次下单相同商品个数',
 '交易行为_180天内多次下单相同商品个数',
 '交易行为_3天内多次成功下单相同商品个数',
 '交易行为_7天内多次成功下单相同商品个数',
 '交易行为_15天内多次成功下单相同商品个数',
 '交易行为_30天内多次成功下单相同商品个数',
 '交易行为_90天内多次成功下单相同商品个数',
 '交易行为_180天内多次成功下单相同商品个数',
 '交易行为_3天内多次下单相同商品金额',
 '交易行为_7天内多次下单相同商品金额',
 '交易行为_15天内多次下单相同商品金额',
 '交易行为_30天内多次下单相同商品金额',
 '交易行为_90天内多次下单相同商品金额',
 '交易行为_180天内多次下单相同商品金额',
 '交易行为_3天内多次成功下单相同商品金额',
 '交易行为_7天内多次成功下单相同商品金额',
 '交易行为_15天内多次成功下单相同商品金额',
 '交易行为_30天内多次成功下单相同商品金额',
 '交易行为_90天内多次成功下单相同商品金额',
 '交易行为_180天内多次成功下单相同商品金额',
 '交易行为_3天内多次下单相同三级品类个数',
 '交易行为_7天内多次下单相同三级品类个数',
 '交易行为_15天内多次下单相同三级品类个数',
 '交易行为_30天内多次下单相同三级品类个数',
 '交易行为_90天内多次下单相同三级品类个数',
 '交易行为_180天内多次下单相同三级品类个数',
 '交易行为_3天内多次成功下单相同三级品类个数',
 '交易行为_7天内多次成功下单相同三级品类个数',
 '交易行为_15天内多次成功下单相同三级品类个数',
 '交易行为_30天内多次成功下单相同三级品类个数',
 '交易行为_90天内多次成功下单相同三级品类个数',
 '交易行为_180天内多次成功下单相同三级品类个数',
 '交易行为_3天内多次下单相同三级品类金额',
 '交易行为_7天内多次下单相同三级品类金额',
 '交易行为_15天内多次下单相同三级品类金额',
 '交易行为_30天内多次下单相同三级品类金额',
 '交易行为_90天内多次下单相同三级品类金额',
 '交易行为_180天内多次下单相同三级品类金额',
 '交易行为_3天内多次成功下单相同三级品类金额',
 '交易行为_7天内多次成功下单相同三级品类金额',
 '交易行为_15天内多次成功下单相同三级品类金额',
 '交易行为_30天内多次成功下单相同三级品类金额',
 '交易行为_90天内多次成功下单相同三级品类金额',
 '交易行为_180天内多次成功下单相同三级品类金额',
 '交易行为_3天内多次下单相同二级品类个数',
 '交易行为_7天内多次下单相同二级品类个数',
 '交易行为_15天内多次下单相同二级品类个数',
 '交易行为_30天内多次下单相同二级品类个数',
 '交易行为_90天内多次下单相同二级品类个数',
 '交易行为_180天内多次下单相同二级品类个数',
 '交易行为_3天内多次成功下单相同二级品类个数',
 '交易行为_7天内多次成功下单相同二级品类个数',
 '交易行为_15天内多次成功下单相同二级品类个数',
 '交易行为_30天内多次成功下单相同二级品类个数',
 '交易行为_90天内多次成功下单相同二级品类个数',
 '交易行为_180天内多次成功下单相同二级品类个数',
 '交易行为_3天内多次下单相同二级品类金额',
 '交易行为_7天内多次下单相同二级品类金额',
 '交易行为_15天内多次下单相同二级品类金额',
 '交易行为_30天内多次下单相同二级品类金额',
 '交易行为_90天内多次下单相同二级品类金额',
 '交易行为_180天内多次下单相同二级品类金额',
 '交易行为_3天内多次成功下单相同二级品类金额',
 '交易行为_7天内多次成功下单相同二级品类金额',
 '交易行为_15天内多次成功下单相同二级品类金额',
 '交易行为_30天内多次成功下单相同二级品类金额',
 '交易行为_90天内多次成功下单相同二级品类金额',
 '交易行为_180天内多次成功下单相同二级品类金额',
 '交易行为_3天内多次下单相同一级品类个数',
 '交易行为_7天内多次下单相同一级品类个数',
 '交易行为_15天内多次下单相同一级品类个数',
 '交易行为_30天内多次下单相同一级品类个数',
 '交易行为_90天内多次下单相同一级品类个数',
 '交易行为_180天内多次下单相同一级品类个数',
 '交易行为_3天内多次成功下单相同一级品类个数',
 '交易行为_7天内多次成功下单相同一级品类个数',
 '交易行为_15天内多次成功下单相同一级品类个数',
 '交易行为_30天内多次成功下单相同一级品类个数',
 '交易行为_90天内多次成功下单相同一级品类个数',
 '交易行为_180天内多次成功下单相同一级品类个数',
 '交易行为_3天内多次下单相同一级品类金额',
 '交易行为_7天内多次下单相同一级品类金额',
 '交易行为_15天内多次下单相同一级品类金额',
 '交易行为_30天内多次下单相同一级品类金额',
 '交易行为_90天内多次下单相同一级品类金额',
 '交易行为_180天内多次下单相同一级品类金额',
 '交易行为_3天内多次成功下单相同一级品类金额',
 '交易行为_7天内多次成功下单相同一级品类金额',
 '交易行为_15天内多次成功下单相同一级品类金额',
 '交易行为_30天内多次成功下单相同一级品类金额',
 '交易行为_90天内多次成功下单相同一级品类金额',
 '交易行为_180天内多次成功下单相同一级品类金额',
#  '商品分期模型分',
#  '借款模型分',
 'staging_amo',
]

ftr_ctg =[
 '性别',
]

# %%
# dummy
enc = OneHotEncoder()
category_df = enc.fit_transform(repayinfo[ftr_ctg]).toarray()

category_ftr = []
for i, vl in enumerate(enc.categories_):
    for v in vl:
        try:
            category_ftr.append(ftr_ctg[i]+'_'+v)
        except:
            category_ftr.append(ftr_ctg[i]+'_'+'空')
        
onehot_df = pd.DataFrame(category_df, columns=category_ftr)

# %%
repayinfo = repayinfo.join(onehot_df)
ftr_dummy = list(onehot_df.columns)

# %%
# 特征及target
target = 'mob3_dpd15_ind'
sample_valid = repayinfo[repayinfo[target.replace('p','')]==1].copy(deep=True)
# sample_valid = sample_valid[(sample_valid['品类']=='高风险套现')&(sample_valid['下单时间']<'2022-05-01')].reset_index(drop=True)
sample_valid = sample_valid[sample_valid['品类']=='高风险套现'].reset_index(drop=True)

# %%
sample_valid.shape
# Out:
# (12371, 399)

# %%
# sample_valid.to_csv('./output/sample_高风险套现.csv', index=0)

# %% [markdown]
# # 分箱及指标

# %%
cov_df = coverage_calc(sample_valid, ftr_ord+ftr_num+ftr_dummy, mi_values=[-9999])
ftr_all = list(cov_df[cov_df['占比']>=60]['变量'])

# %%
# bin_df = pd.DataFrame(columns=[])
# for col in tqdm(ftr_all):    
#     # 重要指标
#     col_df = get_metrics(sample_valid, col, target, '2022-01-01')
#     bin_df = bin_df.append(col_df, ignore_index=True)

# %%
# bin_df[['特征','分箱','个数','KS','IV','minlift','maxlift','minliftcut','maxliftcut','bestks','bestkscut','a占比','e占比','PSI']].to_csv('./output/bin_df_d15.csv', index=0)

# %%
bin_df = pd.read_csv('./output/bin_df_d15.csv')

# %% [markdown]
# # 特征选择

# %% [markdown]
# ## 显著性特征

# %%
sift_df = bin_df.groupby('特征')['KS','IV','minlift','maxlift','minliftcut','maxliftcut','bestks','bestkscut','PSI'].agg('max').reset_index()

# %%
sift_df.to_csv('./output/sift_df_d15_高风险套现.csv', index=0)

# %%
# sift_df.sort_values(by='maxlift', ascending=False)

sift_df.sort_values(by='bestks', ascending=False)

# sift_df.sort_values(by='KS', ascending=False)
# Out:
#                                     特征        KS            IV   minlift  \
# 309                               留存时间  0.014757  1.519811e-03  0.458000
# 152                       同盾近1800天查询次数  0.014463  1.684687e-03  0.411105
# 158                          同盾近7天查询次数  0.019265  1.647983e-03  0.818861
# 154                         同盾近30天查询次数  0.034509  8.651289e-03  0.799429
# 122    关联地址_3天内收货地址610米内被多个下单高套现风险新户使用  0.085477  4.600584e-02  0.901829
# 104   关联地址_15天内收货地址610米内被多个下单高套现风险新户使用  0.071942  3.247125e-02  0.915160
# 128    关联地址_7天内收货地址610米内被多个下单高套现风险新户使用  0.081104  4.022584e-02  0.907443
# 117          关联地址_30天内收货地址610米内被多个新户使用  0.081596  3.628318e-02  0.895603
# 129           关联地址_7天内收货地址610米内被多个新户使用  0.080098  3.897538e-02  0.909244
# 159                         同盾近90天查询次数  0.060290  1.754455e-02  0.723079
# 116   关联地址_30天内收货地址610米内被多个下单高套现风险新户使用  0.066225  2.566939e-02  0.910183
# 157                        同盾近720天查询次数  0.039388  8.327456e-03  0.732456
# 123           关联地址_3天内收货地址610米内被多个新户使用  0.078238  4.067476e-02  0.913463
# 105          关联地址_15天内收货地址610米内被多个新户使用  0.074873  3.379932e-02  0.915550
# 134   关联地址_90天内收货地址610米内被多个下单高套现风险新户使用  0.063022  2.154388e-02  0.919105
# 135          关联地址_90天内收货地址610米内被多个新户使用  0.060050  2.095519e-02  0.918737
# 120           关联地址_30天内收货地址76米内被多个新户使用  0.063005  2.447377e-02  0.926253
# 141            关联地址_收货地址610米内30天内注册新户数  0.073215  2.634386e-02  0.906295
# 119    关联地址_30天内收货地址76米内被多个下单高套现风险新户使用  0.069044  2.648519e-02  0.916908
# 311             百融按身份证号查询_近12个月申请其他的次数  0.013828  2.867353e-03  0.862180
# 153                        同盾近180天查询次数  0.025347  8.537557e-03  0.813389
# 110  关联地址_180天内收货地址610米内被多个下单高套现风险新户使用  0.052990  1.639135e-02  0.924424
# 111         关联地址_180天内收货地址610米内被多个新户使用  0.064309  2.674166e-02  0.907767
# 305                  收货行为_检测省份和收货省份不一致  0.068738  2.304377e-02  0.915067
# 302                  收货行为_检测城市和收货城市不一致  0.068368  2.139549e-02  0.911373
# 107    关联地址_15天内收货地址76米内被多个下单高套现风险新户使用  0.064680  2.272024e-02  0.924259
# 108           关联地址_15天内收货地址76米内被多个新户使用  0.053754  1.636822e-02  0.929324
# 125     关联地址_3天内收货地址76米内被多个下单高套现风险新户使用  0.067336  2.911910e-02  0.926199
# 131     关联地址_7天内收货地址76米内被多个下单高套现风险新户使用  0.066805  2.567451e-02  0.923947
# 178                                 年龄  0.067251  2.224776e-02  0.481865
# 140           关联地址_收货地址610米内180天内注册新户数  0.060171  2.481379e-02  0.902021
# 139            关联地址_收货地址610米内15天内注册新户数  0.066894  2.684051e-02  0.921868
# 137    关联地址_90天内收货地址76米内被多个下单高套现风险新户使用  0.063408  2.072444e-02  0.920733
# 138           关联地址_90天内收货地址76米内被多个新户使用  0.058980  1.911975e-02  0.921451
# 132            关联地址_7天内收货地址76米内被多个新户使用  0.062932  2.695879e-02  0.929801
# 144            关联地址_收货地址610米内90天内注册新户数  0.061572  2.458335e-02  0.917092
# 126            关联地址_3天内收货地址76米内被多个新户使用  0.061515  2.357327e-02  0.931765
# 113   关联地址_180天内收货地址76米内被多个下单高套现风险新户使用  0.061266  1.930881e-02  0.921711
# 310          百融按手机号查询_近6个月在非银机构最大月申请次数  0.011964  1.404345e-03  0.871529
# 146            关联地址_收货地址76米内180天内注册新户数  0.051394  1.588855e-02  0.938123
# 150             关联地址_收货地址76米内90天内注册新户数  0.053794  1.855599e-02  0.936346
# 151                         同盾近15天查询次数  0.029962  7.573861e-03  0.814806
# 114          关联地址_180天内收货地址76米内被多个新户使用  0.046322  1.336578e-02  0.930735
# 166                      多次下单_30天内多次借款  0.047277  1.817540e-02  0.795751
# 145             关联地址_收货地址76米内15天内注册新户数  0.041048  1.303010e-02  0.953206
# 143             关联地址_收货地址610米内7天内注册新户数  0.046684  1.493284e-02  0.949321
# 180                               性别_M  0.045230  8.658597e-03  0.897410
# 179                               性别_F  0.045230  8.658597e-03  0.897410
# 147             关联地址_收货地址76米内30天内注册新户数  0.042763  1.212096e-02  0.953068
# 312            百融按身份证号查询_近3个月在非银机构申请次数  0.020437  3.778984e-03  0.821742
# 218              手机号码_30天内收货手机关联多人借款下单  0.044555  1.012331e-02  0.858291
# 48             交易行为_30天内多次成功下单相同一级品类金额  0.028383  4.887385e-03  0.909098
# 156                        同盾近540天查询次数  0.029550  5.814322e-03  0.952928
# 299               收货行为_手机归属地省份和收货省份不一致  0.043312  8.005908e-03  0.938455
# 32            交易行为_180天内多次成功下单相同一级品类金额  0.025428  4.003358e-03  0.843836
# 96             交易行为_90天内多次成功下单相同一级品类金额  0.025428  4.003358e-03  0.843836
# 50             交易行为_30天内多次成功下单相同三级品类金额  0.030736  4.720439e-03  0.862904
# 34            交易行为_180天内多次成功下单相同三级品类金额  0.031670  4.693057e-03  0.832174
# 98             交易行为_90天内多次成功下单相同三级品类金额  0.031670  4.693057e-03  0.832174
# 115     关联地址_30天内收货地址610米内被多个下单易套现新户使用  0.040542  8.942313e-03  0.833453
# 297               收货行为_手机归属地城市和收货城市不一致  0.040374  6.531756e-03  0.931003
# 149              关联地址_收货地址76米内7天内注册新户数  0.034139  1.141651e-02  0.961441
# 226             手机号码_30天内紧急联系人关联多人借款下单  0.039209  9.338799e-03  0.864699
# 52             交易行为_30天内多次成功下单相同二级品类金额  0.019124  2.353396e-03  0.852610
# 155                        同盾近360天查询次数  0.027001  4.328720e-03  0.949533
# 0                          staging_amo  0.026890  1.261802e-02  0.726777
# 36            交易行为_180天内多次成功下单相同二级品类金额  0.019253  2.368206e-03  0.797005
# 100            交易行为_90天内多次成功下单相同二级品类金额  0.019253  2.368206e-03  0.797005
# 92               交易行为_90天内多次下单相同二级品类金额  0.027267  4.309673e-03  0.773961
# 142             关联地址_收货地址610米内3天内注册新户数  0.035146  1.107420e-02  0.963786
# 16             交易行为_15天内多次成功下单相同一级品类金额  0.023812  2.827013e-03  0.958501
# 109    关联地址_180天内收货地址610米内被多个下单易套现新户使用  0.017328  2.147974e-03  0.818188
# 28              交易行为_180天内多次下单相同二级品类金额  0.029296  4.230927e-03  0.769341
# 118      关联地址_30天内收货地址76米内被多个下单易套现新户使用  0.033722  6.487877e-03  0.891207
# 18             交易行为_15天内多次成功下单相同三级品类金额  0.028441  4.450631e-03  0.951460
# 103     关联地址_15天内收货地址610米内被多个下单易套现新户使用  0.033505  6.071048e-03  0.950491
# 148              关联地址_收货地址76米内3天内注册新户数  0.033229  1.338897e-02  0.967106
# 82              交易行为_7天内多次成功下单相同三级品类金额  0.025380  3.974211e-03  0.955614
# 20             交易行为_15天内多次成功下单相同二级品类金额  0.022097  2.908091e-03  0.946965
# 64              交易行为_3天内多次成功下单相同一级品类金额  0.018721  2.135121e-03  0.965740
# 90               交易行为_90天内多次下单相同三级品类金额  0.019343  6.737513e-03  0.814310
# 49             交易行为_30天内多次成功下单相同三级品类个数  0.029979  6.621985e-03  0.462813
# 30                交易行为_180天内多次下单相同商品金额  0.020578  3.426435e-03  0.808149
# 97             交易行为_90天内多次成功下单相同三级品类个数  0.029488  7.484822e-03  0.428210
# 33            交易行为_180天内多次成功下单相同三级品类个数  0.029488  7.484822e-03  0.428210
# 80              交易行为_7天内多次成功下单相同一级品类金额  0.027409  6.208263e-03  0.963829
# 163                     多次下单_180天内多次借款  0.022661  6.007103e-03  0.908583
# 24              交易行为_180天内多次下单相同一级品类金额  0.025256  4.921671e-03  0.850419
# 66              交易行为_3天内多次成功下单相同三级品类金额  0.020880  2.001308e-03  0.963124
# 106      关联地址_15天内收货地址76米内被多个下单易套现新户使用  0.027997  7.691858e-03  0.879247
# 94                 交易行为_90天内多次下单相同商品金额  0.019692  3.388636e-03  0.789395
# 91               交易行为_90天内多次下单相同二级品类个数  0.027782  4.393202e-03  0.810570
# 17             交易行为_15天内多次成功下单相同三级品类个数  0.027693  3.191097e-03  0.279381
# 88               交易行为_90天内多次下单相同一级品类金额  0.023870  2.670904e-03  0.832798
# 315     百融近12个月_通过手机号查询_在银行_区域银行机构申请次数  0.014926  2.535070e-03  0.772832
# 317     百融近6个月_通过手机号查询_在银行_区域银行机构申请机构数  0.014857  2.597626e-03  0.889192
# 186              手机号码_15天内收货手机关联多人借款下单  0.026728  3.079202e-03  0.935322
# 27              交易行为_180天内多次下单相同二级品类个数  0.026615  3.580832e-03  0.709394
# 26              交易行为_180天内多次下单相同三级品类金额  0.014101  2.512515e-03  0.812909
# 68              交易行为_3天内多次成功下单相同二级品类金额  0.015018  1.386148e-03  0.969144
# 84              交易行为_7天内多次成功下单相同二级品类金额  0.024454  4.432672e-03  0.966123
# 160                      多次下单_15天内多次借款  0.024707  8.465089e-03  0.893073
# 6                    下单行为_90天内虚拟订单取消个数  0.024001  5.316167e-03  0.836458
# 60                交易行为_3天内多次下单相同二级品类金额  0.013812  8.207283e-04  0.946252
# 313            百融按身份证号查询_近6个月在非银机构申请次数  0.035208  6.889411e-03  0.639141
# 314    百融近12个月_通过手机号查询_在银行_区域银行机构申请机构数  0.021464  5.167664e-03  0.830594
# 76                交易行为_7天内多次下单相同二级品类金额  0.017163  1.818808e-03  0.793155
# 81              交易行为_7天内多次成功下单相同三级品类个数  0.022757  2.146174e-03  0.888514
# 194             手机号码_15天内紧急联系人关联多人借款下单  0.022501           inf  0.000000
# 3                    下单行为_30天内虚拟订单取消个数  0.021674  4.547709e-03  0.843331
# 172                       多次下单_7天内多次借款  0.021117  5.673364e-03  0.826236
# 65              交易行为_3天内多次成功下单相同三级品类个数  0.020880  1.889048e-03  0.820532
# 29                交易行为_180天内多次下单相同商品个数  0.020715  3.537998e-03  0.851174
# 203            手机号码_180天内收货手机关联多人易套现下单  0.020513           inf  0.000000
# 47             交易行为_30天内多次成功下单相同一级品类个数  0.020511  4.980506e-03  0.401917
# 46                 交易行为_30天内多次下单相同商品金额  0.008936  8.164266e-04  0.821331
# 164              多次下单_180天内购买多个易套现类别商品  0.020320  2.525330e-03  0.814131
# 95             交易行为_90天内多次成功下单相同一级品类个数  0.020020  5.635209e-03  0.371000
# 31            交易行为_180天内多次成功下单相同一级品类个数  0.020020  5.635209e-03  0.371000
# 2                   下单行为_180天内虚拟订单取消个数  0.019910  3.546695e-03  0.867057
# 176               多次下单_90天内购买多个易套现类别商品  0.019910  3.544768e-03  0.902486
# 267             手机号码_90天内收货手机关联多人易套现下单  0.019837           inf  0.000000
# 316     百融近3个月_通过手机号查询_在银行_区域银行机构申请机构数  0.009090  2.161715e-03  0.916239
# 89               交易行为_90天内多次下单相同三级品类个数  0.019343  1.968101e-03  0.829712
# 93                 交易行为_90天内多次下单相同商品个数  0.019234  3.287052e-03  0.852702
# 136      关联地址_90天内收货地址76米内被多个下单易套现新户使用  0.018900  2.146322e-03  0.974572
# 10               交易行为_15天内多次下单相同三级品类金额  0.011559  3.681794e-03  0.901192
# 15             交易行为_15天内多次成功下单相同一级品类个数  0.018852  1.584265e-03  0.254547
# 304               收货行为_检测省份和手机归属地省份不一致  0.018560  2.821282e-03  0.980419
# 70                交易行为_3天内多次成功下单相同商品金额  0.016427  1.853409e-03  0.956056
# 1                    下单行为_15天内虚拟订单取消个数  0.018389  3.648607e-03  0.849108
# 8                交易行为_15天内多次下单相同一级品类金额  0.015235  4.846872e-03  0.932004
# 301               收货行为_检测城市和手机归属地城市不一致  0.018231  1.649890e-03  0.977136
# 74                交易行为_7天内多次下单相同三级品类金额  0.009844  1.681858e-03  0.896166
# 72                交易行为_7天内多次下单相同一级品类金额  0.016945  2.905034e-03  0.802660
# 86                交易行为_7天内多次成功下单相同商品金额  0.014149  1.041114e-03  0.889172
# 5                     下单行为_7天内虚拟订单取消个数  0.017705  3.898316e-03  0.831306
# 303              收货行为_检测城市和身份证归属地城市不一致  0.017478  1.512407e-03  0.944645
# 14                 交易行为_15天内多次下单相同商品金额  0.009113  9.003991e-04  0.860362
# 51             交易行为_30天内多次成功下单相同二级品类个数  0.017041  4.353728e-03  0.434299
# 78                  交易行为_7天内多次下单相同商品金额  0.012285  1.450492e-03  0.853106
# 22               交易行为_15天内多次成功下单相同商品金额  0.013464  9.029095e-04  0.800893
# 38              交易行为_180天内多次成功下单相同商品金额  0.013988  9.706374e-04  0.696441
# 102              交易行为_90天内多次成功下单相同商品金额  0.013988  9.706374e-04  0.696441
# 12               交易行为_15天内多次下单相同二级品类金额  0.013039  3.234759e-03  0.904894
# 175                      多次下单_90天内多次借款  0.009820  1.337599e-03  0.913900
# 35            交易行为_180天内多次成功下单相同二级品类个数  0.016373  5.210313e-03  0.403687
# 99             交易行为_90天内多次成功下单相同二级品类个数  0.016373  5.210313e-03  0.403687
# 58                交易行为_3天内多次下单相同三级品类金额  0.005334  1.249346e-04  0.926346
# 19             交易行为_15天内多次成功下单相同二级品类个数  0.016171  1.151968e-03  0.270582
# 211           手机号码_180天内紧急联系人关联多人易套现下单  0.016149           inf  0.000000
# 25              交易行为_180天内多次下单相同三级品类个数  0.016140  1.248618e-03  0.840006
# 23              交易行为_180天内多次下单相同一级品类个数  0.013779  1.692391e-03  0.735965
# 44               交易行为_30天内多次下单相同二级品类金额  0.012241  5.215352e-03  0.929137
# 275            手机号码_90天内紧急联系人关联多人易套现下单  0.015956           inf  0.000000
# 266              手机号码_90天内收货手机关联多人借款下单  0.000000  0.000000e+00  0.922487
# 4                     下单行为_3天内虚拟订单取消个数  0.015917  3.724700e-03  0.819012
# 56                交易行为_3天内多次下单相同一级品类金额  0.006105  6.654127e-04  0.954552
# 75                交易行为_7天内多次下单相同二级品类个数  0.015639  1.578258e-03  0.923419
# 165            多次下单_180天内购买多个高套现风险类别商品  0.013428  2.315526e-03  0.721697
# 308              收货行为_身份证归属地省份和收货省份不一致  0.015373  1.155639e-03  0.980502
# 87               交易行为_90天内多次下单相同一级品类个数  0.015349  1.750016e-03  0.787986
# 54               交易行为_30天内多次成功下单相同商品金额  0.013770  9.331114e-04  0.741400
# 112     关联地址_180天内收货地址76米内被多个下单易套现新户使用  0.007940  5.957840e-04  0.977357
# 63              交易行为_3天内多次成功下单相同一级品类个数  0.014955  9.733692e-04  0.850742
# 202             手机号码_180天内收货手机关联多人借款下单  0.000000  0.000000e+00  0.913708
# 177             多次下单_90天内购买多个高套现风险类别商品  0.014465  1.810528e-03  0.774983
# 85                交易行为_7天内多次成功下单相同商品个数  0.014149  1.216149e-03  0.967997
# 45                 交易行为_30天内多次下单相同商品个数  0.014000  2.094313e-03  0.897973
# 37              交易行为_180天内多次成功下单相同商品个数  0.013988  2.218435e-03  0.600617
# 101              交易行为_90天内多次成功下单相同商品个数  0.013988  2.218435e-03  0.600617
# 59                交易行为_3天内多次下单相同二级品类个数  0.013812  1.173162e-03  0.975682
# 53               交易行为_30天内多次成功下单相同商品个数  0.013770  2.156612e-03  0.619169
# 42               交易行为_30天内多次下单相同三级品类金额  0.010163           inf  0.937463
# 174              多次下单_7天内购买多个高套现风险类别商品  0.013493  1.965964e-03  0.900007
# 21               交易行为_15天内多次成功下单相同商品个数  0.013464  1.346947e-03  0.744551
# 71                交易行为_7天内多次下单相同一级品类个数  0.013445  2.024844e-03  0.909754
# 133     关联地址_90天内收货地址610米内被多个下单易套现新户使用  0.013442  1.496686e-03  0.895421
# 69                交易行为_3天内多次成功下单相同商品个数  0.013239  9.668830e-04  0.984241
# 40               交易行为_30天内多次下单相同一级品类金额  0.008151  1.629885e-03  0.917782
# 11               交易行为_15天内多次下单相同二级品类个数  0.013039  7.151037e-04  0.963678
# 77                  交易行为_7天内多次下单相同商品个数  0.012632  1.712719e-03  0.915557
# 67              交易行为_3天内多次成功下单相同二级品类个数  0.012563  7.104788e-04  0.845014
# 307              收货行为_身份证归属地城市和收货城市不一致  0.012290  6.259385e-04  0.981251
# 43               交易行为_30天内多次下单相同二级品类个数  0.012241  1.660164e-03  0.942063
# 13                 交易行为_15天内多次下单相同商品个数  0.012189  1.664028e-03  0.908137
# 169                       多次下单_3天内多次借款  0.012076  1.177579e-03  0.894170
# 130       关联地址_7天内收货地址76米内被多个下单易套现新户使用  0.012046  1.042918e-03  0.707076
# 243             手机号码_3天内紧急联系人关联多人易套现下单  0.011642  1.422598e-03  0.000000
# 306              收货行为_检测省份和身份证归属地省份不一致  0.011609  1.119495e-03  0.926853
# 83              交易行为_7天内多次成功下单相同二级品类个数  0.011469  5.525313e-04  0.891678
# 170                多次下单_3天内购买多个易套现类别商品  0.011239  1.338319e-03  0.906965
# 79              交易行为_7天内多次成功下单相同一级品类个数  0.011203  5.758219e-04  0.876071
# 318                       百行循环借贷累计逾期次数  0.008069  1.513343e-03  0.633694
# 162             多次下单_15天内购买多个高套现风险类别商品  0.005374  8.524447e-04  0.938664
# 62                  交易行为_3天内多次下单相同商品金额  0.003775  3.919268e-04  0.916034
# 282           收货行为_180天内使用多个不同城市地址下单商品  0.009961  8.872111e-04  0.959885
# 167               多次下单_30天内购买多个易套现类别商品  0.009693  6.448574e-04  0.951143
# 300           收货行为_手机归属地省份和身份证归属地省份不一致  0.009389  7.916308e-04  0.990219
# 278                  手机号码_注册手机和收货手机不一致  0.009058  1.430378e-03  0.991228
# 234               手机号码_3天内收货手机关联多人借款下单  0.008982  3.359610e-04  0.979733
# 206           手机号码_180天内紧急联系人以注册手机下单借款  0.008615  1.891700e-03  0.991830
# 168             多次下单_30天内购买多个高套现风险类别商品  0.008376  1.447214e-03  0.933905
# 7                交易行为_15天内多次下单相同一级品类个数  0.005430  7.555374e-04  0.948378
# 235              手机号码_3天内收货手机关联多人易套现下单  0.007672  6.089358e-04  0.000000
# 250               手机号码_7天内收货手机关联多人借款下单  0.007573  2.296321e-04  0.985795
# 298           收货行为_手机归属地城市和身份证归属地城市不一致  0.007571  2.893617e-04  0.990547
# 73                交易行为_7天内多次下单相同三级品类个数  0.007459  2.427980e-04  0.949568
# 161               多次下单_15天内购买多个易套现类别商品  0.007358  4.063537e-04  0.913559
# 41               交易行为_30天内多次下单相同三级品类个数  0.003522  1.449646e-04  0.962189
# 9                交易行为_15天内多次下单相同三级品类个数  0.005422  2.337238e-04  0.989906
# 259             手机号码_7天内紧急联系人关联多人易套现下单  0.006641  3.760740e-04  0.000000
# 39               交易行为_30天内多次下单相同一级品类个数  0.006621  1.133202e-03  0.942621
# 258              手机号码_7天内紧急联系人关联多人借款下单  0.006574           inf  0.000000
# 121      关联地址_3天内收货地址610米内被多个下单易套现新户使用  0.006571  3.280553e-04  0.992917
# 219             手机号码_30天内收货手机关联多人易套现下单  0.006528  2.874744e-04  0.000000
# 242              手机号码_3天内紧急联系人关联多人借款下单  0.006486           inf  0.000000
# 205             手机号码_180天内紧急联系人以注册手机下单  0.006425  9.271385e-04  0.993865
# 173                多次下单_7天内购买多个易套现类别商品  0.006279  3.404684e-04  0.875942
# 284           收货行为_180天内使用多个不同省份地址下单商品  0.006257  4.127729e-04  0.608210
# 201               手机号码_180天内收货手机关联多人下单  0.006079  7.085655e-03  0.333630
# 127      关联地址_7天内收货地址610米内被多个下单易套现新户使用  0.006048  2.966157e-04  0.991655
# 171              多次下单_3天内购买多个高套现风险类别商品  0.005938  2.488010e-04  0.990094
# 61                  交易行为_3天内多次下单相同商品个数  0.005740  6.113512e-04  0.953873
# 55                交易行为_3天内多次下单相同一级品类个数  0.005712  2.281448e-04  0.990451
# 285            收货行为_30天内使用多个不同城市地址下单商品  0.005629  3.581495e-04  0.831384
# 294            收货行为_90天内使用多个不同城市地址下单商品  0.005508  2.964435e-04  0.864500
# 227            手机号码_30天内紧急联系人关联多人易套现下单  0.005474  2.009378e-04  0.000000
# 57                交易行为_3天内多次下单相同三级品类个数  0.005334  4.968097e-04  0.990445
# 124       关联地址_3天内收货地址76米内被多个下单易套现新户使用  0.001521  2.090255e-05  0.732259
# 204          手机号码_180天内收货手机关联多人高风险套现下单  0.005056  6.682389e-03  0.286366
# 265                手机号码_90天内收货手机关联多人下单  0.005016  5.200241e-03  0.377625
# 279            收货行为_15天内使用多个不同城市地址下单商品  0.004896  3.127551e-04  0.596595
# 289               收货行为_3天内使用多个不同收货手机下单  0.004581  1.597172e-03  0.995770
# 296            收货行为_90天内使用多个不同省份地址下单商品  0.000458  2.427893e-06  0.535263
# 251              手机号码_7天内收货手机关联多人易套现下单  0.004258  1.539485e-04  0.000000
# 268           手机号码_90天内收货手机关联多人高风险套现下单  0.004171  4.935969e-03  0.327275
# 269              手机号码_90天内紧急联系人以注册手机下单  0.004107  4.246324e-04  0.996097
# 283             收货行为_180天内使用多个不同收货手机下单  0.004066  5.556493e-04  0.885520
# 292               收货行为_7天内使用多个不同收货手机下单  0.003857  8.678163e-04  0.996423
# 256          手机号码_7天内紧急联系人以注册手机下单高风险套现  0.003639  8.098215e-04  0.996627
# 281            收货行为_15天内使用多个不同省份地址下单商品  0.001626  4.096860e-05  0.363639
# 272         手机号码_90天内紧急联系人以注册手机下单高风险套现  0.003470  4.926280e-04  0.996756
# 217                手机号码_30天内收货手机关联多人下单  0.003422  2.758953e-03  0.470738
# 293             收货行为_7天内使用多个不同省份地址下单商品  0.002455  1.125703e-04  0.233768
# 233                 手机号码_3天内收货手机关联多人下单  0.003277           inf  0.000000
# 288             收货行为_3天内使用多个不同城市地址下单商品  0.003253  2.041930e-04  0.747041
# 271           手机号码_90天内紧急联系人以注册手机下单易套现  0.003221  9.303916e-04  0.997031
# 208        手机号码_180天内紧急联系人以注册手机下单高风险套现  0.003205  4.178280e-04  0.997003
# 222            手机号码_30天内紧急联系人以注册手机下单借款  0.003172  5.629301e-04  0.851997
# 276          手机号码_90天内紧急联系人关联多人高风险套现下单  0.003076  2.490361e-03  0.997185
# 212         手机号码_180天内紧急联系人关联多人高风险套现下单  0.002899  2.146443e-03  0.997347
# 287            收货行为_30天内使用多个不同省份地址下单商品  0.001545  3.195938e-05  0.643519
# 291             收货行为_7天内使用多个不同城市地址下单商品  0.002794  1.216180e-04  0.776585
# 295              收货行为_90天内使用多个不同收货手机下单  0.002729  2.718552e-04  0.915108
# 185                手机号码_15天内收货手机关联多人下单  0.002625  1.752949e-03  0.536936
# 187             手机号码_15天内收货手机关联多人易套现下单  0.002519  4.643523e-05  0.000000
# 220           手机号码_30天内收货手机关联多人高风险套现下单  0.002399  1.999632e-03  0.458185
# 240          手机号码_3天内紧急联系人以注册手机下单高风险套现  0.002375  4.512263e-04  0.997806
# 197              手机号码_180天内收货手机以注册手机下单  0.002351  2.976930e-03  0.301438
# 189              手机号码_15天内紧急联系人以注册手机下单  0.002343  1.869057e-04  0.997797
# 236            手机号码_3天内收货手机关联多人高风险套现下单  0.002303           inf  0.000000
# 214             手机号码_30天内收货手机以注册手机下单借款  0.002303           inf  0.000000
# 253               手机号码_7天内紧急联系人以注册手机下单  0.002279  2.149737e-04  0.997869
# 200         手机号码_180天内收货手机以注册手机下单高风险套现  0.002214           inf  0.000000
# 257                手机号码_7天内紧急联系人关联多人下单  0.002190  1.102507e-03  0.997994
# 261               手机号码_90天内收货手机以注册手机下单  0.002174  2.631451e-03  0.318184
# 210            手机号码_180天内紧急联系人关联多人借款下单  0.002142  8.637391e-04  0.998036
# 198            手机号码_180天内收货手机以注册手机下单借款  0.002085  2.463610e-03  0.327275
# 274             手机号码_90天内紧急联系人关联多人借款下单  0.002013  9.097291e-04  0.993077
# 188           手机号码_15天内收货手机关联多人高风险套现下单  0.001956  1.414484e-03  0.509095
# 264          手机号码_90天内收货手机以注册手机下单高风险套现  0.001948           inf  0.000000
# 216          手机号码_30天内收货手机以注册手机下单高风险套现  0.001948           inf  0.000000
# 255            手机号码_7天内紧急联系人以注册手机下单易套现  0.001924  8.220138e-04  0.998237
# 213               手机号码_30天内收货手机以注册手机下单  0.001908  2.138323e-03  0.347110
# 184          手机号码_15天内收货手机以注册手机下单高风险套现  0.001860           inf  0.000000
# 195            手机号码_15天内紧急联系人关联多人易套现下单  0.001859  2.520833e-05  0.000000
# 193               手机号码_15天内紧急联系人关联多人下单  0.001836  7.397804e-04  0.998318
# 262             手机号码_90天内收货手机以注册手机下单借款  0.001820  1.981143e-03  0.357957
# 286              收货行为_30天内使用多个不同收货手机下单  0.001739  1.290558e-04  0.935836
# 238             手机号码_3天内紧急联系人以注册手机下单借款  0.001699  6.442661e-04  0.704900
# 182             手机号码_15天内收货手机以注册手机下单借款  0.001683           inf  0.000000
# 209              手机号码_180天内紧急联系人关联多人下单  0.001667  3.841722e-04  0.809923
# 181               手机号码_15天内收货手机以注册手机下单  0.001642  1.678456e-03  0.381821
# 229                手机号码_3天内收货手机以注册手机下单  0.001506           inf  0.000000
# 237               手机号码_3天内紧急联系人以注册手机下单  0.001466  1.170291e-04  0.998638
# 244           手机号码_3天内紧急联系人关联多人高风险套现下单  0.001417           inf  0.000000
# 221              手机号码_30天内紧急联系人以注册手机下单  0.001393  5.682708e-05  0.998683
# 273               手机号码_90天内紧急联系人关联多人下单  0.001264  2.607363e-04  0.828046
# 270            手机号码_90天内紧急联系人以注册手机下单借款  0.001240  5.297087e-05  0.998834
# 248           手机号码_7天内收货手机以注册手机下单高风险套现  0.001240           inf  0.000000
# 199           手机号码_180天内收货手机以注册手机下单易套现  0.001151           inf  0.000000
# 280              收货行为_15天内使用多个不同收货手机下单  0.001143  6.174470e-05  0.998934
# 249                 手机号码_7天内收货手机关联多人下单  0.001119  3.801189e-04  0.731147
# 190            手机号码_15天内紧急联系人以注册手机下单借款  0.001119  9.392892e-05  0.926964
# 232           手机号码_3天内收货手机以注册手机下单高风险套现  0.001063           inf  0.000000
# 290             收货行为_3天内使用多个不同省份地址下单商品  0.001038  2.462234e-05  0.979541
# 263            手机号码_90天内收货手机以注册手机下单易套现  0.000974           inf  0.000000
# 191           手机号码_15天内紧急联系人以注册手机下单易套现  0.000950  1.791120e-04  0.999129
# 252            手机号码_7天内收货手机关联多人高风险套现下单  0.000894  3.527343e-04  0.694220
# 245                手机号码_7天内收货手机以注册手机下单  0.000845  5.491136e-04  0.545459
# 246              手机号码_7天内收货手机以注册手机下单借款  0.000797           inf  0.000000
# 224         手机号码_30天内紧急联系人以注册手机下单高风险套现  0.000797  3.123175e-05  0.965524
# 241                手机号码_3天内紧急联系人关联多人下单  0.000692  1.438047e-04  0.999366
# 215            手机号码_30天内收货手机以注册手机下单易套现  0.000620           inf  0.000000
# 183            手机号码_15天内收货手机以注册手机下单易套现  0.000620           inf  0.000000
# 207          手机号码_180天内紧急联系人以注册手机下单易套现  0.000588  2.640395e-05  0.960268
# 230              手机号码_3天内收货手机以注册手机下单借款  0.000531           inf  0.000000
# 247             手机号码_7天内收货手机以注册手机下单易套现  0.000531           inf  0.000000
# 192         手机号码_15天内紧急联系人以注册手机下单高风险套现  0.000451  1.132838e-05  0.999581
# 239            手机号码_3天内紧急联系人以注册手机下单易套现  0.000386  5.805422e-05  0.999646
# 223           手机号码_30天内紧急联系人以注册手机下单易套现  0.000370  2.193674e-05  0.999660
# 231             手机号码_3天内收货手机以注册手机下单易套现  0.000354           inf  0.000000
# 225               手机号码_30天内紧急联系人关联多人下单  0.000330  2.033716e-05  0.999697
# 228          手机号码_30天内紧急联系人关联多人高风险套现下单  0.000274  3.781265e-05  0.881125
# 196          手机号码_15天内紧急联系人关联多人高风险套现下单  0.000185  1.768133e-05  0.916370
# 260           手机号码_7天内紧急联系人关联多人高风险套现下单  0.000169  1.622008e-05  0.999845
# 254             手机号码_7天内紧急联系人以注册手机下单借款  0.000008  7.979643e-09  0.999993
# 277                 手机号码_收货手机和紧急联系人不一致  0.000000  0.000000e+00  1.000000
#
#       maxlift  minliftcut  maxliftcut    bestks  bestkscut           PSI
# 309  1.493478     1493.00        3.00  0.114093     574.00  1.038478e-01
# 152  1.484522      151.00       43.00  0.104916      74.00  1.630109e-03
# 158  1.694917        2.00       11.00  0.094508       5.00  7.931414e-04
# 154  1.604696        7.00       19.00  0.088473      12.00  5.681583e-04
# 122  1.583589        1.00        5.00  0.085477       1.00  1.134916e-02
# 104  1.820528        9.00       16.00  0.082481       9.00  1.660601e-02
# 128  1.767414        1.00       10.00  0.081797       3.00  1.324434e-02
# 117  1.688824        2.00       33.00  0.081596       2.00  1.685476e-02
# 129  1.746446        2.00       10.00  0.080098       2.00  1.069789e-02
# 159  1.622961       14.00       28.00  0.079979      18.00  2.478064e-03
# 116  1.753367        2.00       21.00  0.079977      10.00  2.431620e-02
# 157  1.562766       71.00       32.00  0.078532      46.00  2.503649e-03
# 123  1.538811        1.00        4.00  0.078238       2.00  9.497840e-03
# 105  1.738372        2.00       16.00  0.077239       9.00  1.235020e-02
# 134  1.668347       14.00       34.00  0.075629      14.00  3.292721e-02
# 135  1.558581        2.00       37.00  0.073930      16.00  2.367693e-02
# 120  1.751885       14.00       14.00  0.073584      14.00  1.553658e-02
# 141  1.438099        1.00       10.00  0.073215       1.00  1.719418e-02
# 119  1.801852        1.00       33.00  0.072183      13.00  1.503898e-02
# 311  1.433772        3.00        9.00  0.070963       3.00  1.543970e-03
# 153  1.264435       24.00       41.00  0.069363      25.00  1.145340e-03
# 110  1.576411       12.00       36.00  0.068922      12.00  3.160412e-02
# 111  1.538918        3.00      106.00  0.068777      16.00  2.508825e-02
# 305  1.240062        0.00        0.00  0.068738       0.00  4.493766e-03
# 302  1.210855        0.00        0.00  0.068368       0.00  2.887436e-03
# 107  1.794679        1.00       11.00  0.068262       9.00  9.493967e-03
# 108  1.761365        5.00       11.00  0.067972       5.00  8.687273e-03
# 125  1.676287        1.00        5.00  0.067336       1.00  6.288991e-03
# 131  1.747548        1.00        9.00  0.067288       2.00  7.642187e-03
# 178  1.462601       24.00       40.00  0.067251      29.00  2.389397e-03
# 140  1.590019        1.00       35.00  0.067063       3.00  1.725431e-02
# 139  1.512555        1.00        6.00  0.066894       1.00  7.200421e-03
# 137  1.944134        1.00       49.00  0.065275      16.00  2.474941e-02
# 138  1.818195        1.00       56.00  0.063423      21.00  2.157474e-02
# 132  1.692609        1.00        9.00  0.062932       2.00  8.435345e-03
# 144  1.532858        1.00        9.00  0.062159       3.00  2.498210e-02
# 126  1.611839        1.00        5.00  0.061515       1.00  6.453435e-03
# 113  1.876189        1.00       48.00  0.061266       1.00  2.281862e-02
# 310  1.213684       15.00       30.00  0.060351      18.00  2.493955e-02
# 146  1.740102        3.00       13.00  0.059976      13.00  1.117787e-02
# 150  1.720763        1.00        8.00  0.057698       7.00  1.292821e-02
# 151  1.625519        5.00       14.00  0.056860       9.00  1.307609e-03
# 114  1.776485        2.00       67.00  0.056571      11.00  1.914751e-02
# 166  1.057789        5.00        0.00  0.047277       0.00  2.296111e-02
# 145  1.639584        2.00        5.00  0.047014       2.00  1.263851e-02
# 143  1.614150        1.00        4.00  0.046684       1.00  4.873088e-03
# 180  1.069078        0.00        0.00  0.045230       0.00  1.923852e-06
# 179  1.069078        0.00        0.00  0.045230       0.00  1.923852e-06
# 147  1.712290        1.00        7.00  0.044896       3.00  1.684666e-02
# 312  1.159816       15.00       51.00  0.044567      32.00  2.294455e-02
# 218  1.057031        0.00        0.00  0.044555       0.00  8.270725e-03
# 48   1.167297     6044.46     4578.00  0.044543    3789.00  9.056572e-02
# 156  1.397167       34.00       27.00  0.043458      34.00  2.127718e-03
# 299  1.110517        0.00        0.00  0.043312       0.00  7.926877e-03
# 32   1.146156     6074.00     3801.00  0.042901    3789.00  8.871692e-02
# 96   1.146156     6074.00     3801.00  0.042901    3789.00  8.871692e-02
# 50   1.177925     5945.00     4340.00  0.042852    3789.00  6.239909e-02
# 34   1.151812     5945.00     4340.00  0.041387    3789.00  7.243752e-02
# 98   1.151812     5945.00     4340.00  0.041387    3789.00  7.243752e-02
# 115  1.098423        3.00        0.00  0.040542       0.00  8.401937e-03
# 297  1.079088        0.00        0.00  0.040374       0.00  2.527547e-03
# 149  1.809787        2.00        3.00  0.039751       2.00  1.258341e-02
# 226  1.832741        0.00        1.00  0.039209       0.00  1.421486e-02
# 52   1.143730     6001.00     4340.00  0.038456    3801.00  8.396320e-02
# 155  1.547718       43.00       54.00  0.037718      43.00  3.034505e-03
# 0    1.119345      820.00     4100.00  0.036946    1947.70  2.586498e-01
# 36   1.130085     6027.00     3801.00  0.036902    3801.00  8.409075e-02
# 100  1.130085     6027.00     3801.00  0.036902    3801.00  8.409075e-02
# 92   1.074199    25277.00      969.00  0.036068    6210.00  8.066227e-02
# 142  1.952167        1.00        3.00  0.035146       1.00  6.651755e-03
# 16   1.177821     3789.00     5598.00  0.034656    3789.00  5.757873e-02
# 109  1.138120        9.00        2.00  0.034350       2.00  7.980028e-04
# 28   1.071746    28696.00      969.00  0.034288    6210.00  7.596433e-02
# 118  1.123221        2.00        0.00  0.033722       0.00  3.166427e-02
# 18   1.144307     1959.36     4340.00  0.033657    3789.00  6.479205e-02
# 103  1.105524        2.00        0.00  0.033505       0.00  5.250736e-03
# 148  1.753015        1.00        2.00  0.033229       1.00  1.882852e-02
# 82   1.147228     1956.00     4942.00  0.031806    1956.00  4.602706e-02
# 20   1.144033     5884.00     5773.00  0.030936    3789.00  4.682645e-02
# 64   1.233026     1950.00     4303.00  0.030476    3725.00  4.142049e-02
# 90   1.047876    24926.00      419.00  0.030335    6210.00  6.616445e-02
# 49   1.090260        3.00        1.00  0.029979       0.00  6.952447e-02
# 30   1.031618     7762.00     4216.00  0.029725    4216.00  3.283779e-02
# 97   1.090265        3.00        1.00  0.029488       0.00  6.966870e-02
# 33   1.090265        3.00        1.00  0.029488       0.00  6.966870e-02
# 80   1.226638     1956.00     5598.00  0.029076    3788.33  4.072813e-02
# 163  1.088006        0.00        9.00  0.028934       3.00  3.664688e-02
# 24   1.049719    31062.00      862.00  0.028444   12763.00  5.806072e-02
# 66   1.148469     1950.00     3801.00  0.028110    1959.00  5.304040e-02
# 106  1.123530        1.00        0.00  0.027997       0.00  2.111750e-02
# 94   1.029618     8468.00     4206.00  0.027986    4206.00  3.274517e-02
# 91   1.070753        9.00        0.00  0.027782       1.00  7.626193e-02
# 17   1.074032        3.00        1.00  0.027693       0.00  5.716640e-02
# 88   1.046350    24765.00      862.00  0.027638    6210.00  6.576663e-02
# 315  1.279082        3.00       25.00  0.027464       8.00  7.337615e-03
# 317  1.185353        2.00        8.00  0.026971       2.00  4.795605e-04
# 186  1.039168        0.00        0.00  0.026728       0.00  1.561922e-02
# 27   1.062223       10.00        0.00  0.026615       1.00  7.612767e-02
# 26   1.039888    28161.00     3949.00  0.026430    6210.00  8.794866e-02
# 68   1.184324     1950.00     4301.00  0.026137    3801.00  4.236007e-02
# 84   1.184324     1956.00     5544.00  0.025919    3788.33  4.413888e-02
# 160  1.034612        4.00        0.00  0.024707       0.00  2.803873e-02
# 6    1.205750        0.00        1.00  0.024001       0.00  2.400984e-01
# 60   1.118169    12763.00     9745.00  0.023297    2040.00  4.370070e-02
# 313  1.274068      121.00       28.00  0.023215      94.00  3.733686e-02
# 314  1.049813        2.00       13.00  0.023213       6.00  6.895633e-03
# 76   1.058831    15954.00     9745.00  0.022758    2040.00  6.905742e-02
# 81   1.054631        2.00        1.00  0.022757       0.00  5.956146e-02
# 194  1.032014        1.00        0.00  0.022501       0.00  2.537263e-02
# 3    1.272737        0.00        1.00  0.021674       0.00  2.430455e-01
# 172  1.025104        3.00        1.00  0.021117       1.00  2.504909e-02
# 65   1.055336        2.00        1.00  0.020880       0.00  6.330450e-02
# 29   1.023347        2.00        1.00  0.020715       1.00  3.957374e-02
# 203  1.024817        1.00        0.00  0.020513       0.00  5.760074e-03
# 47   1.078575        3.00        1.00  0.020511       0.00  6.264610e-02
# 46   1.021264     7762.00     4206.00  0.020426    4206.00  2.897775e-02
# 164  1.024457        3.00        0.00  0.020320       0.00  1.449974e-02
# 95   1.076719        3.00        1.00  0.020020       0.00  6.278771e-02
# 31   1.076719        3.00        1.00  0.020020       0.00  6.278771e-02
# 2    1.186038        0.00        1.00  0.019910       0.00  2.311786e-01
# 176  1.023242        3.00        0.00  0.019910       0.00  2.341753e-02
# 267  1.023266        1.00        0.00  0.019837       0.00  5.885210e-03
# 316  1.098600        1.00        7.00  0.019548       1.00  2.182877e-04
# 89   1.047437        9.00        0.00  0.019343       0.00  8.610976e-02
# 93   1.021519        2.00        1.00  0.019234       1.00  3.924712e-02
# 136  1.118262        0.00        2.00  0.018900       0.00  2.596274e-02
# 10   1.104876    15032.00     9821.00  0.018874    9821.00  1.004200e-01
# 15   1.057134        3.00        1.00  0.018852       0.00  4.991556e-02
# 304  1.125560        0.00        0.00  0.018560       0.00  1.616701e-04
# 70   1.114442     3940.00     3801.00  0.018552    1950.00  3.435609e-02
# 1    1.029127        0.00        1.00  0.018389       0.00  2.256448e-01
# 8    1.087006    15032.00     9736.00  0.018270    9736.00  6.433395e-02
# 301  1.061118        0.00        0.00  0.018231       0.00  1.792900e-03
# 74   1.085391    15032.00     9745.00  0.017936    3989.00  7.184717e-02
# 72   1.057075    16182.00     9745.00  0.017863    3989.00  7.061698e-02
# 86   1.074400     3981.00     1950.00  0.017844    1917.00  6.840194e-02
# 5    1.245068        0.00        1.00  0.017705       0.00  2.015259e-01
# 303  1.022410        0.00        0.00  0.017478       0.00  7.302072e-03
# 14   1.019875     7762.00     2103.00  0.017253    4206.00  3.298890e-02
# 51   1.059641        3.00        1.00  0.017041       0.00  6.216061e-02
# 78   1.018711     4206.00     2103.00  0.016899    3940.00  2.441614e-02
# 22   1.064439     4066.00     1950.00  0.016894    1905.00  8.883914e-02
# 38   1.056826     4134.00     1950.00  0.016803    4134.00  8.100876e-02
# 102  1.056826     4134.00     1950.00  0.016803    4134.00  8.100876e-02
# 12   1.084840    15032.00     9821.00  0.016744    3949.00  9.641189e-02
# 175  1.155736        0.00        8.00  0.016547       5.00  4.565347e-02
# 35   1.059087        3.00        1.00  0.016373       0.00  6.216958e-02
# 99   1.059087        3.00        1.00  0.016373       0.00  6.216958e-02
# 58   1.138928    12763.00     9745.00  0.016236    2040.00  5.579876e-02
# 19   1.048905        3.00        1.00  0.016171       0.00  5.062803e-02
# 211  1.019554        1.00        0.00  0.016149       0.00  6.415452e-03
# 25   1.035723        9.00        0.00  0.016140       1.00  8.577436e-02
# 23   1.040252       10.00        0.00  0.016093       3.00  7.145192e-02
# 44   1.053192    12763.00     9821.00  0.016076    6210.00  6.247002e-02
# 275  1.018718        1.00        0.00  0.015956       0.00  7.307729e-03
# 266  1.017911        0.00        0.00  0.015941       0.00  0.000000e+00
# 4    1.050883        0.00        1.00  0.015917       0.00  1.683340e-01
# 56   1.122845    10796.00     9745.00  0.015809    2040.00  4.994235e-02
# 75   1.033764        3.00        0.00  0.015639       0.00  6.052577e-02
# 165  1.038609       10.00        0.00  0.015441       3.00  7.098050e-02
# 308  1.050035        0.00        0.00  0.015373       0.00  8.261637e-04
# 87   1.042876        9.00        0.00  0.015349       0.00  7.077203e-02
# 54   1.056181     4128.00     1950.00  0.015348    1905.00  8.328989e-02
# 112  1.180029        4.00        2.00  0.015323       2.00  1.588543e-02
# 63   1.047198        2.00        1.00  0.014955       0.00  5.751946e-02
# 202  1.015590        0.00        0.00  0.014467       0.00  0.000000e+00
# 177  1.039513        9.00        0.00  0.014465       1.00  6.984103e-02
# 85   1.050158        2.00        0.00  0.014149       0.00  3.551851e-02
# 45   1.015347        2.00        1.00  0.014000       1.00  3.529252e-02
# 37   1.044881        2.00        0.00  0.013988       0.00  3.557255e-02
# 101  1.044881        2.00        0.00  0.013988       0.00  3.557255e-02
# 59   1.026940        1.00        0.00  0.013812       0.00  6.033088e-02
# 53   1.044297        2.00        0.00  0.013770       0.00  3.491405e-02
# 42   1.066585    15032.00     9821.57  0.013617    9821.57  9.569815e-02
# 174  1.017734        6.00        0.00  0.013493       3.00  5.606823e-02
# 21   1.045031        2.00        0.00  0.013464       0.00  3.446534e-02
# 71   1.020912        6.00        0.00  0.013445       3.00  5.620770e-02
# 133  1.050325        6.00        1.00  0.013442       0.00  1.025877e-02
# 69   1.070526        0.00        2.00  0.013239       0.00  4.141225e-02
# 40   1.050810    22860.00     9020.00  0.013209    3801.00  7.112751e-02
# 11   1.030373        7.00        0.00  0.013039       0.00  6.360871e-02
# 77   1.013352        1.00        1.00  0.012632       1.00  3.065093e-02
# 67   1.044022        2.00        1.00  0.012563       0.00  5.844951e-02
# 307  1.027920        0.00        0.00  0.012290       0.00  2.992818e-03
# 43   1.043171        8.00        5.00  0.012241       0.00  6.890388e-02
# 13   1.013189        2.00        1.00  0.012189       1.00  3.313922e-02
# 169  1.014723        2.00        0.00  0.012076       1.00  1.904420e-02
# 130  1.067804        1.00        0.00  0.012046       0.00  1.636296e-02
# 243  1.011959        1.00        0.00  0.011642       0.00  4.795556e-03
# 306  1.012390        0.00        0.00  0.011609       0.00  4.247206e-03
# 83   1.031791        2.00        1.00  0.011469       0.00  5.359497e-02
# 170  1.011529        0.00        0.00  0.011239       0.00  7.397066e-03
# 79   1.038269        2.00        1.00  0.011203       0.00  5.261835e-02
# 318  1.010023        1.00        1.00  0.010683       1.00  9.857377e-05
# 162  1.036506        6.00        2.00  0.010469       2.00  5.939481e-02
# 62   1.102775     3952.00     6006.00  0.010136    3952.00  5.297046e-02
# 282  1.073173        2.00        1.00  0.009961       1.00  2.080566e-03
# 167  1.048390        0.00        2.00  0.009693       0.00  8.141687e-03
# 300  1.069198        0.00        0.00  0.009389       0.00  2.306494e-03
# 278  1.143852        0.00        0.00  0.009058       0.00  1.835869e-02
# 234  1.013767        0.00        0.00  0.008982       0.00  1.171106e-02
# 206  1.209648        0.00        0.00  0.008615       0.00  6.618629e-03
# 168  1.026655        8.00        2.00  0.008376       2.00  6.472161e-02
# 7    1.029030        6.00        2.00  0.008271       2.00  6.015792e-02
# 235  1.007882        1.00        0.00  0.007672       0.00  3.440736e-03
# 250  1.013461        0.00        0.00  0.007573       0.00  1.508808e-02
# 298  1.025685        0.00        0.00  0.007571       0.00  2.880305e-03
# 73   1.023974        3.00        5.00  0.007459       0.00  6.398559e-02
# 161  1.008007        2.00        0.00  0.007358       0.00  5.946234e-03
# 41   1.077576        8.00        5.00  0.007303       5.00  7.600624e-02
# 9    1.044848        7.00        5.00  0.006669       2.00  7.087085e-02
# 259  1.007036        1.00        0.00  0.006641       0.00  2.346442e-03
# 39   1.021225        6.00        2.00  0.006621       2.00  6.544302e-02
# 258  1.011319        1.00        0.00  0.006574       0.00  2.211614e-02
# 121  1.039133        0.00        0.00  0.006571       0.00  1.286415e-02
# 219  1.007300        1.00        0.00  0.006528       0.00  2.733766e-03
# 242  1.010187        1.00        0.00  0.006486       0.00  1.769459e-02
# 205  1.132875        0.00        0.00  0.006425       0.00  4.076879e-03
# 173  1.006635        2.00        0.00  0.006279       0.00  5.377135e-03
# 284  1.055149        2.00        1.00  0.006257       1.00  1.991080e-03
# 201  1.005595        1.00        1.00  0.006079       1.00  1.798752e-02
# 127  1.025917        1.00        0.00  0.006048       0.00  1.516559e-02
# 171  1.029127        0.00        5.00  0.005938       0.00  5.481228e-02
# 61   1.037770        1.00        2.00  0.005740       1.00  3.594658e-02
# 55   1.031141        0.00        5.00  0.005712       0.00  5.589054e-02
# 285  1.053633        2.00        1.00  0.005629       1.00  9.924038e-04
# 294  1.044297        2.00        1.00  0.005508       1.00  2.787208e-03
# 227  1.006127        1.00        0.00  0.005474       0.00  3.235275e-03
# 57   1.036618        0.00        5.00  0.005334       0.00  6.675247e-02
# 124  1.004825        1.00        1.00  0.005193       1.00  1.972635e-02
# 204  1.004645        1.00        1.00  0.005056       1.00  1.283122e-02
# 265  1.004612        1.00        1.00  0.005016       1.00  2.668012e-02
# 279  1.054733        2.00        1.00  0.004896       1.00  8.987982e-05
# 289  1.361739        1.00        1.00  0.004581       1.00  7.949557e-04
# 296  1.004055        2.00        2.00  0.004404       2.00  2.404310e-03
# 251  1.004509        1.00        0.00  0.004258       0.00  1.519112e-03
# 268  1.003828        1.00        1.00  0.004171       1.00  1.780214e-02
# 269  1.094243        0.00        0.00  0.004107       0.00  3.260820e-03
# 283  1.003835        1.00        1.00  0.004066       1.00  3.574676e-04
# 292  1.221052        1.00        1.00  0.003857       1.00  6.966676e-04
# 256  1.218578        0.00        0.00  0.003639       0.00  4.056678e-03
# 281  1.003257        2.00        2.00  0.003551       2.00  4.851266e-05
# 272  1.133735        0.00        0.00  0.003470       0.00  4.704526e-03
# 217  1.003142        1.00        1.00  0.003422       1.00  3.421788e-02
# 293  1.003047        2.00        2.00  0.003325       2.00  1.672408e-04
# 233  1.003000        1.00        1.00  0.003277       1.00  5.851940e-05
# 288  1.055487        2.00        1.00  0.003253       1.00  3.077764e-04
# 271  1.293265        0.00        0.00  0.003221       0.00  1.226678e-03
# 208  1.122244        0.00        0.00  0.003205       0.00  4.906171e-03
# 222  1.002953        0.00        0.00  0.003172       0.00  7.401309e-04
# 276  2.021405        1.00        1.00  0.003076       1.00  2.940097e-04
# 212  1.909105        1.00        1.00  0.002899       1.00  5.837020e-04
# 287  1.002583        2.00        2.00  0.002810       2.00  8.321764e-04
# 291  1.037606        2.00        1.00  0.002794       1.00  7.305592e-05
# 295  1.002566        1.00        1.00  0.002729       1.00  1.856618e-04
# 185  1.002408        1.00        1.00  0.002625       1.00  3.744596e-02
# 187  1.002751        1.00        0.00  0.002519       0.00  1.376604e-03
# 220  1.002199        1.00        1.00  0.002399       1.00  2.281235e-02
# 240  1.184962        0.00        0.00  0.002375       0.00  4.310773e-03
# 197  1.002152        0.00        0.00  0.002351       0.00  1.433889e-02
# 189  1.072885        0.00        0.00  0.002343       0.00  2.626850e-03
# 236  1.002106        1.00        1.00  0.002303       1.00  2.886340e-05
# 214  1.002106        0.00        0.00  0.002303       0.00  1.841524e-02
# 253  1.087219        0.00        0.00  0.002279       0.00  4.159206e-03
# 200  1.002025        0.00        0.00  0.002214       0.00  1.009058e-02
# 257  1.561995        1.00        1.00  0.002190       1.00  1.668131e-04
# 261  1.001990        0.00        0.00  0.002174       0.00  1.823569e-02
# 210  1.431829        1.00        1.00  0.002142       1.00  2.024054e-03
# 198  1.001909        0.00        0.00  0.002085       0.00  1.236427e-02
# 274  1.494082        0.00        1.00  0.002013       1.00  1.909180e-03
# 188  1.001792        1.00        1.00  0.001956       1.00  2.552779e-02
# 264  1.001782        0.00        0.00  0.001948       0.00  1.465503e-02
# 216  1.001782        0.00        0.00  0.001948       0.00  1.465503e-02
# 255  1.462293        0.00        0.00  0.001924       0.00  2.165266e-03
# 213  1.001746        0.00        0.00  0.001908       0.00  1.591916e-02
# 184  1.001700        0.00        0.00  0.001860       0.00  1.881978e-05
# 195  1.002031        1.00        0.00  0.001859       0.00  2.023203e-03
# 193  1.431829        1.00        1.00  0.001836       1.00  1.157207e-06
# 262  1.001665        0.00        0.00  0.001820       0.00  1.868753e-02
# 286  1.001627        1.00        1.00  0.001739       1.00  8.095483e-04
# 238  1.001559        0.00        0.00  0.001699       0.00  2.359118e-03
# 182  1.001538        0.00        0.00  0.001683       0.00  1.194090e-02
# 209  1.001533        1.00        1.00  0.001667       1.00  7.369478e-04
# 181  1.001503        0.00        0.00  0.001642       0.00  2.231291e-02
# 229  1.001376        0.00        0.00  0.001506       0.00  1.232804e-05
# 237  1.073872        0.00        0.00  0.001466       0.00  5.354594e-03
# 244  1.001295        1.00        1.00  0.001417       1.00  5.071781e-04
# 221  1.036498        0.00        0.00  0.001393       0.00  1.959496e-03
# 273  1.001161        1.00        1.00  0.001264       1.00  7.078883e-04
# 270  1.038469        0.00        0.00  0.001240       0.00  4.373277e-03
# 248  1.001133        0.00        0.00  0.001240       0.00  8.358288e-06
# 199  1.001052        0.00        0.00  0.001151       0.00  6.859843e-03
# 280  1.049279        1.00        1.00  0.001143       1.00  1.455071e-03
# 249  1.001025        1.00        1.00  0.001119       1.00  9.452431e-05
# 190  1.001036        0.00        0.00  0.001119       0.00  5.555538e-04
# 232  1.000971        0.00        0.00  0.001063       0.00  6.139513e-06
# 290  1.000994        1.00        1.00  0.001038       1.00  3.443412e-04
# 263  1.000890        0.00        0.00  0.000974       0.00  5.298900e-03
# 191  1.184962        0.00        0.00  0.000950       0.00  3.599895e-03
# 252  1.000818        1.00        1.00  0.000894       1.00  4.653117e-05
# 245  1.000773        0.00        0.00  0.000845       0.00  1.881978e-05
# 246  1.000728        0.00        0.00  0.000797       0.00  3.452405e-06
# 224  1.000743        0.00        0.00  0.000797       0.00  6.507468e-03
# 241  1.205750        1.00        1.00  0.000692       1.00  3.270386e-04
# 215  1.000566        0.00        0.00  0.000620       0.00  2.088061e-06
# 183  1.000566        0.00        0.00  0.000620       0.00  2.088061e-06
# 207  1.000544        0.00        0.00  0.000588       0.00  6.345178e-03
# 230  1.000485        0.00        0.00  0.000531       0.00  1.533927e-06
# 247  1.000485        0.00        0.00  0.000531       0.00  1.533927e-06
# 192  1.022735        0.00        0.00  0.000451       0.00  4.996798e-03
# 239  1.145463        0.00        0.00  0.000386       0.00  2.432129e-03
# 223  1.055032        0.00        0.00  0.000370       0.00  2.293790e-03
# 231  1.000323        0.00        0.00  0.000354       0.00  6.816045e-07
# 225  1.057350        1.00        1.00  0.000330       1.00  4.758286e-05
# 228  1.000250        1.00        1.00  0.000274       1.00  1.879975e-06
# 196  1.000169        1.00        1.00  0.000185       1.00  2.434779e-06
# 260  1.090917        1.00        1.00  0.000169       1.00  3.602177e-04
# 254  1.000890        0.00        0.00  0.000008       0.00  4.364517e-04
# 277  1.000000        1.00        1.00  0.000000       1.00  0.000000e+00

# %%
# selection = lambda x: True if x['PSI']<0.1 and ((x['maxlift']>=1.5 or x['minlift']<=0.5 and x['minlift']!=0) or (x['IV']>=0.1 and x['IV']!=np.inf)) else False
selection = lambda x: True if x['PSI']<0.1 and ((x['maxlift']>=1.5 or x['bestks']>=0.06) or (x['IV']>=0.1 and x['IV']!=np.inf)) else False
# selection = lambda x: True if x['PSI']<0.1 else False
# selection = lambda x: True if (x['maxlift']>=1.6) or (x['IV']>=0.1 and x['IV']!=np.inf) else False
select_list = sift_df[sift_df.apply(selection, axis=1)]['特征'].tolist()
select_list
# Out:
# ['关联地址_15天内收货地址610米内被多个下单高套现风险新户使用',
#  '关联地址_15天内收货地址610米内被多个新户使用',
#  '关联地址_15天内收货地址76米内被多个下单高套现风险新户使用',
#  '关联地址_15天内收货地址76米内被多个新户使用',
#  '关联地址_180天内收货地址610米内被多个下单高套现风险新户使用',
#  '关联地址_180天内收货地址610米内被多个新户使用',
#  '关联地址_180天内收货地址76米内被多个下单高套现风险新户使用',
#  '关联地址_180天内收货地址76米内被多个新户使用',
#  '关联地址_30天内收货地址610米内被多个下单高套现风险新户使用',
#  '关联地址_30天内收货地址610米内被多个新户使用',
#  '关联地址_30天内收货地址76米内被多个下单高套现风险新户使用',
#  '关联地址_30天内收货地址76米内被多个新户使用',
#  '关联地址_3天内收货地址610米内被多个下单高套现风险新户使用',
#  '关联地址_3天内收货地址610米内被多个新户使用',
#  '关联地址_3天内收货地址76米内被多个下单高套现风险新户使用',
#  '关联地址_3天内收货地址76米内被多个新户使用',
#  '关联地址_7天内收货地址610米内被多个下单高套现风险新户使用',
#  '关联地址_7天内收货地址610米内被多个新户使用',
#  '关联地址_7天内收货地址76米内被多个下单高套现风险新户使用',
#  '关联地址_7天内收货地址76米内被多个新户使用',
#  '关联地址_90天内收货地址610米内被多个下单高套现风险新户使用',
#  '关联地址_90天内收货地址610米内被多个新户使用',
#  '关联地址_90天内收货地址76米内被多个下单高套现风险新户使用',
#  '关联地址_90天内收货地址76米内被多个新户使用',
#  '关联地址_收货地址610米内15天内注册新户数',
#  '关联地址_收货地址610米内180天内注册新户数',
#  '关联地址_收货地址610米内30天内注册新户数',
#  '关联地址_收货地址610米内3天内注册新户数',
#  '关联地址_收货地址610米内7天内注册新户数',
#  '关联地址_收货地址610米内90天内注册新户数',
#  '关联地址_收货地址76米内15天内注册新户数',
#  '关联地址_收货地址76米内180天内注册新户数',
#  '关联地址_收货地址76米内30天内注册新户数',
#  '关联地址_收货地址76米内3天内注册新户数',
#  '关联地址_收货地址76米内7天内注册新户数',
#  '关联地址_收货地址76米内90天内注册新户数',
#  '同盾近15天查询次数',
#  '同盾近1800天查询次数',
#  '同盾近180天查询次数',
#  '同盾近30天查询次数',
#  '同盾近360天查询次数',
#  '同盾近720天查询次数',
#  '同盾近7天查询次数',
#  '同盾近90天查询次数',
#  '年龄',
#  '手机号码_180天内紧急联系人关联多人高风险套现下单',
#  '手机号码_30天内紧急联系人关联多人借款下单',
#  '手机号码_7天内紧急联系人关联多人下单',
#  '手机号码_90天内紧急联系人关联多人高风险套现下单',
#  '收货行为_检测城市和收货城市不一致',
#  '收货行为_检测省份和收货省份不一致',
#  '百融按手机号查询_近6个月在非银机构最大月申请次数',
#  '百融按身份证号查询_近12个月申请其他的次数']

# %% [markdown]
# ## 模型筛选

# %%
# x = sample_valid[ftr_all]
# y = sample_valid[target]

# %%
# model = ExtraTreesClassifier(random_state=0)
# clf_s = model.fit(x, y)

# %%
# list(enumerate(sorted(list(zip(ftr_all, clf_s.feature_importances_)), key=lambda x: x[1], reverse=True)))

# %%
# ftr_importance = dict(zip(ftr_all, clf_s.feature_importances_))

# %%
# select_list = [k for k,v in ftr_importance.items() if v>=0.005]
# select_list

# %% [markdown]
# ## 相关性

# %%
corr = sample_valid[ftr_all].corr()
# corr.to_csv('./output/corr_20220722.csv')

# %%
# 选相关性高的
while True:
    l = len(select_list)
    tmp_corr = sample_valid[select_list].corr()
    corr_matrix = np.array(tmp_corr)
    corr_pair_list = []
    for i in range(l):
        pair_list = []
        for j in range(l):
            if abs(corr_matrix[i][j])>=0.8:
                pair_list.append(select_list[j])
        corr_pair_list.append(pair_list)

    # 删除子集
    corr_pair_list_compressed = list(filter(lambda f: not any(set(f) < set(g) for g in corr_pair_list), corr_pair_list))

    # 筛指标最高的
    selected = set()
    for f in corr_pair_list_compressed:
    # for f in corr_pair_list:
        selected.add(sorted(f, key = lambda x: float(sift_df[sift_df['特征']==x]['bestks']), reverse=True)[0])
#         selected.add(sorted(f, key = lambda x: ftr_importance[x], reverse=True)[0])

    if selected == set(select_list):
        break

    select_list = list(selected)

# %%
selected = sorted(select_list)
selected
# Out:
# ['关联地址_3天内收货地址610米内被多个下单高套现风险新户使用',
#  '关联地址_收货地址610米内30天内注册新户数',
#  '同盾近15天查询次数',
#  '同盾近1800天查询次数',
#  '年龄',
#  '手机号码_30天内紧急联系人关联多人借款下单',
#  '手机号码_90天内紧急联系人关联多人高风险套现下单',
#  '收货行为_检测省份和收货省份不一致',
#  '百融按手机号查询_近6个月在非银机构最大月申请次数',
#  '百融按身份证号查询_近12个月申请其他的次数']

# %% [markdown]
# ## 特征选择

# %%
# selected = ['交易行为_30天内多次下单相同商品个数',
#  '交易行为_90天内多次下单相同二级品类金额',
#  '关联地址_180天内收货地址76米内被多个下单易套现新户使用',
#  '关联地址_90天内收货地址76米内被多个下单高套现风险新户使用',
#  '关联地址_收货地址76米内30天内注册新户数',
#  '同盾近15天查询次数',
#  '同盾近180天查询次数',
#  '多次下单_180天内购买多个易套现类别商品',
#  '手机号码_180天内紧急联系人以注册手机下单',
#  '收货行为_180天内使用多个不同收货手机下单',
#  '收货行为_3天内使用多个不同省份地址下单商品',
#  '留存时间',
#  '百融按手机号查询_近6个月在非银机构最大月申请次数',
#  '百融按身份证号查询_近6个月在非银机构申请次数',
#  '百融近12个月_通过手机号查询_在银行_区域银行机构申请次数',
#  '百融近6个月_通过手机号查询_在银行_区域银行机构申请机构数',
#  '百行循环借贷累计逾期次数']

# %%
# selected = [
#  '关联地址_180天内收货地址610米内被多个新户使用',
#  '关联地址_30天内收货地址610米内被多个新户使用',
#  '借款模型分',
#  '收货行为_180天内使用多个不同收货手机下单',
#  '收货行为_90天内使用多个不同收货手机下单',
#  '关联地址_收货地址76米内7天内注册新户数',
#  '收货行为_15天内使用多个不同收货手机下单',
#  '年龄',
#  '关联地址_30天内收货地址76米内被多个下单易套现新户使用',
#  '手机号码_3天内紧急联系人以注册手机下单易套现',
#  '手机号码_7天内紧急联系人以注册手机下单易套现',
#  '手机号码_30天内收货手机以注册手机下单',
#  '手机号码_180天内紧急联系人关联多人借款下单',
#  '同盾近180天查询次数',
#  '手机号码_180天内收货手机以注册手机下单',
#  '手机号码_90天内紧急联系人以注册手机下单易套现',
#  '手机号码_30天内收货手机关联多人下单',
# ]

# %%
# selected = [
#  '交易行为_3天内多次成功下单相同一级品类金额',
#  '借款模型分',
#  '关联地址_180天内收货地址610米内被多个新户使用',
#  '关联地址_30天内收货地址76米内被多个下单易套现新户使用',
#  '同盾近180天查询次数',
#  '手机号码_180天内紧急联系人关联多人借款下单',
#  '手机号码_30天内收货手机以注册手机下单',
#  '手机号码_30天内收货手机关联多人下单',
#  '手机号码_3天内紧急联系人以注册手机下单易套现',
#  '收货行为_180天内使用多个不同收货手机下单',
#  '年龄',
# ]

# %%
sift_df[sift_df['特征'].isin(selected)].sort_values(by=['bestks'], ascending=False)
# Out:
#                                   特征        KS        IV   minlift   maxlift  \
# 152                     同盾近1800天查询次数  0.014463  0.001685  0.411105  1.484522
# 122  关联地址_3天内收货地址610米内被多个下单高套现风险新户使用  0.085477  0.046006  0.901829  1.583589
# 141          关联地址_收货地址610米内30天内注册新户数  0.073215  0.026344  0.906295  1.438099
# 311           百融按身份证号查询_近12个月申请其他的次数  0.013828  0.002867  0.862180  1.433772
# 305                收货行为_检测省份和收货省份不一致  0.068738  0.023044  0.915067  1.240062
# 178                               年龄  0.067251  0.022248  0.481865  1.462601
# 310        百融按手机号查询_近6个月在非银机构最大月申请次数  0.011964  0.001404  0.871529  1.213684
# 151                       同盾近15天查询次数  0.029962  0.007574  0.814806  1.625519
# 226           手机号码_30天内紧急联系人关联多人借款下单  0.039209  0.009339  0.864699  1.832741
# 276        手机号码_90天内紧急联系人关联多人高风险套现下单  0.003076  0.002490  0.997185  2.021405
#
#      minliftcut  maxliftcut    bestks  bestkscut       PSI
# 152       151.0        43.0  0.104916       74.0  0.001630
# 122         1.0         5.0  0.085477        1.0  0.011349
# 141         1.0        10.0  0.073215        1.0  0.017194
# 311         3.0         9.0  0.070963        3.0  0.001544
# 305         0.0         0.0  0.068738        0.0  0.004494
# 178        24.0        40.0  0.067251       29.0  0.002389
# 310        15.0        30.0  0.060351       18.0  0.024940
# 151         5.0        14.0  0.056860        9.0  0.001308
# 226         0.0         1.0  0.039209        0.0  0.014215
# 276         1.0         1.0  0.003076        1.0  0.000294

# %% [markdown]
# # 模型训练及测试

# %%
sample_cut = sample_valid[selected+[target]+['mob3_dpd15amo','mob3_dpd15amosum']].copy(deep=True)
selected_cut = []
for s in selected:
    sample_cut[s+'_cut'] = pd.cut(sample_cut[s], [-np.inf, float(sift_df[sift_df['特征']==s]['bestkscut']), np.inf])
    selected_cut.append(s+'_cut')

# %%
# dummy
enc = OneHotEncoder()
selected_category_df = enc.fit_transform(sample_cut[selected_cut]).toarray()

selected_category_ftr = []
for i, vl in enumerate(enc.categories_):
    for v in vl:
        try:
            selected_category_ftr.append(selected_cut[i].replace('_cut','')+'_'+str(v))
        except:
            selected_category_ftr.append(selected_cut[i].replace('_cut','')+'_'+'空')
        
selected_onehot_df = pd.DataFrame(selected_category_df, columns=selected_category_ftr)

# %% [markdown]
# ## 提升树

# %%
x = sample_cut[selected+selected_cut+['mob3_dpd15amo','mob3_dpd15amosum']]
y = sample_cut[target]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.4,random_state = 0)

# %% [markdown]
# ### 训练

# %%
tree1 = buildtree(df=pd.concat([x_train, y_train], axis=1), 
                 selectedcol=selected, 
                 max_depth=3, 
                 min_samples_leaf=70
                )

# %%
printtree(tree1)
# Out:
# {0.0: 6755, 1.0: 667, 'con': 0.0933}
# 手机号码_90天内紧急联系人关联多人高风险套现下单>=1?
# T->{0.0: 6664, 1.0: 650, 'con': 0.0917}
# 	同盾近15天查询次数>=17?
# 	T->{0.0: 84, 1.0: 18, 'con': 0.1594}
# 	F->{0.0: 6580, 1.0: 632, 'con': 0.0908}
# 		年龄>=41?
# 		T->{1.0: 61, 0.0: 379, 'con': 0.1486}
# 		F->{0.0: 6201, 1.0: 571, 'con': 0.087}
# F->{0.0: 91, 1.0: 17, 'con': 0.1883}

# %% [markdown]
# ### 验证

# %%
y_pred_proba = x_test.apply(lambda x: classify(x, tree1)['con'], axis=1)

# %%
threshold = []
recall,precision = [],[]
for t in np.arange(0.05,max(y_pred_proba)-0.0001,0.001):
    y_pred = np.array([1 if x>=t else 0 for x in y_pred_proba])
    recall.append(len([y1 for y1,y2 in zip(y_test, y_pred) if y1==1 and y2==1])/len([x for x in y_test if x==1]))
    precision.append(len([y1 for y1,y2 in zip(y_test, y_pred) if y1==1 and y2==1])/len([x for x in y_pred if x==1]))
    threshold.append(t)

# %%
plt.plot(threshold, recall, color='darkorange', label='recall')
plt.plot(threshold, precision, color='navy', label='precision')
diff = list(abs(np.array(recall)-np.array(precision)))
best_threshold_1 = threshold[diff.index(min(diff))]
best_recall = recall[diff.index(min(diff))]
best_precision = precision[diff.index(min(diff))]
text = 'threshold='+str(round(best_threshold_1,2))+'\nrecall='+str(round(best_recall,2))+'\nprecision='+str(round(best_precision,2))
plt.xlim([0.05, max(y_pred_proba)-0.0001])
plt.ylim([0.0, 0.5])
plt.xlabel('Threshold')
plt.ylabel('rate')
plt.title('CUT')
plt.legend(loc="lower right")
plt.annotate(text, xy=(best_threshold_1, best_recall), xytext=(best_threshold_1, best_recall+0.1))
# Out:
# Text(0.08700000000000004, 0.24285714285714285, 'threshold=0.09\nrecall=0.14\nprecision=0.12')

# %% [markdown]
# ### 逾期率

# %%
sample_valid_predict = sample_cut.copy(deep=True)
sample_valid_predict['predict'] = [1 if x>=best_threshold_1 else 0 for x in sample_cut.apply(lambda x: classify(x, tree1)['con'], axis=1)]

# %%
concentration(sample_valid)
# Out:
# 0.08987419942675365

# %%
sample_valid_predict.groupby('predict').apply(concentration)
# Out:
# predict
# 0    0.083626
# 1    0.150428
# dtype: float64

# %%
Counter(sample_valid_predict['predict'])
# Out:
# Counter({0: 11248, 1: 1123})

# %% [markdown]
# ## 预分箱提升树

# %% [markdown]
# ### 训练

# %%
tree2 = buildtree(df=pd.concat([x_train, y_train], axis=1), 
                 selectedcol=selected_cut, 
                 max_depth=3, 
                 min_samples_leaf=70
                )

# %%
printtree(tree2)
# Out:
# {0.0: 6755, 1.0: 667, 'con': 0.0933}
# 关联地址_3天内收货地址610米内被多个下单高套现风险新户使用_cut:(1.0, inf]?
# T->{0.0: 1305, 1.0: 191, 'con': 0.1221}
# 	同盾近15天查询次数_cut:(9.0, inf]?
# 	T->{0.0: 338, 1.0: 65, 'con': 0.1627}
# 		关联地址_收货地址610米内30天内注册新户数_cut:(1.0, inf]?
# 		T->{0.0: 280, 1.0: 48, 'con': 0.1414}
# 		F->{1.0: 17, 0.0: 58, 'con': 0.2559}
# 	F->{0.0: 967, 1.0: 126, 'con': 0.108}
# 		百融按身份证号查询_近12个月申请其他的次数_cut:(3.0, inf]?
# 		T->{0.0: 506, 1.0: 86, 'con': 0.1372}
# 		F->{0.0: 461, 1.0: 40, 'con': 0.075}
# F->{0.0: 5450, 1.0: 476, 'con': 0.0864}
# 	同盾近1800天查询次数_cut:(74.0, inf]?
# 	T->{0.0: 2543, 1.0: 174, 'con': 0.0685}
# 		关联地址_收货地址610米内30天内注册新户数_cut:(1.0, inf]?
# 		T->{0.0: 348, 1.0: 29, 'con': 0.087}
# 		F->{0.0: 2195, 1.0: 145, 'con': 0.0656}
# 	F->{0.0: 2907, 1.0: 302, 'con': 0.101}
# 		年龄_cut:(-inf, 29.0]?
# 		T->{0.0: 1399, 1.0: 124, 'con': 0.0868}
# 		F->{0.0: 1508, 1.0: 178, 'con': 0.1133}

# %% [markdown]
# ### 验证

# %%
y_pred_proba = x_test.apply(lambda x: classify(x, tree2)['con'], axis=1)

# %%
threshold = []
recall,precision = [],[]
for t in np.arange(0.05,max(y_pred_proba)-0.0001,0.001):
    y_pred = np.array([1 if x>=t else 0 for x in y_pred_proba])
    recall.append(len([y1 for y1,y2 in zip(y_test, y_pred) if y1==1 and y2==1])/len([x for x in y_test if x==1]))
    precision.append(len([y1 for y1,y2 in zip(y_test, y_pred) if y1==1 and y2==1])/len([x for x in y_pred if x==1]))
    threshold.append(t)

# %%
plt.plot(threshold, recall, color='darkorange', label='recall')
plt.plot(threshold, precision, color='navy', label='precision')
diff = list(abs(np.array(recall)-np.array(precision)))
best_threshold_2 = threshold[diff.index(min(diff))]
best_recall = recall[diff.index(min(diff))]
best_precision = precision[diff.index(min(diff))]
text = 'threshold='+str(round(best_threshold_2,2))+'\nrecall='+str(round(best_recall,2))+'\nprecision='+str(round(best_precision,2))
plt.xlim([0.05, max(y_pred_proba)-0.0001])
plt.ylim([0.0, 0.5])
plt.xlabel('Threshold')
plt.ylabel('rate')
plt.title('CUT')
plt.legend(loc="lower right")
plt.annotate(text, xy=(best_threshold_2, best_recall), xytext=(best_threshold_2, best_recall+0.1))
# Out:
# Text(0.13800000000000007, 0.18716707021791767, 'threshold=0.14\nrecall=0.09\nprecision=0.12')

# %% [markdown]
# ### 逾期率

# %%
sample_valid_predict = sample_cut.copy(deep=True)
sample_valid_predict['predict'] = [1 if x>=best_threshold_2 else 0 for x in sample_cut.apply(lambda x: classify(x, tree2)['con'], axis=1)]

# %%
concentration(sample_valid)
# Out:
# 0.08987419942675365

# %%
sample_valid_predict.groupby('predict').apply(concentration)
# Out:
# predict
# 0    0.086653
# 1    0.148268
# dtype: float64

# %%
Counter(sample_valid_predict['predict'])
# Out:
# Counter({0: 11677, 1: 694})

# %% [markdown]
# ## 决策树

# %%
x = sample_valid[selected]
# x = selected_onehot_df
y = sample_valid[target]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.4,random_state = 0)

# %% [markdown]
# ### 训练

# %%
model = tree.DecisionTreeClassifier(max_depth=3
                                    ,min_samples_leaf=70
                                    ,class_weight='balanced'
#                                     ,class_weight={0:1, 1:10}
                                    ,random_state=0)
clf = model.fit(x_train,y_train)
# 预测标签
y_pred_proba = clf.predict_proba(x_test)[:,1]
print("测试集的平均正确率：{}".format(clf.score(x_test,y_test)))

# # 计算回归值，取值小于0，表示p(y=1) <0.5,则该处标签属于1，否则属于0
# y_pred1 = clf.predict_proba(x_test)
# Out:
# 测试集的平均正确率：0.30288947262073146

# %%
sorted(list(zip(selected, model.feature_importances_)), key=lambda x: x[1], reverse=True)
# Out:
# [('同盾近1800天查询次数', 0.3812253557160401),
#  ('年龄', 0.24221100588144798),
#  ('百融按手机号查询_近6个月在非银机构最大月申请次数', 0.2016116441922788),
#  ('关联地址_3天内收货地址610米内被多个下单高套现风险新户使用', 0.17495199421023314),
#  ('关联地址_收货地址610米内30天内注册新户数', 0.0),
#  ('同盾近15天查询次数', 0.0),
#  ('手机号码_30天内紧急联系人关联多人借款下单', 0.0),
#  ('手机号码_90天内紧急联系人关联多人高风险套现下单', 0.0),
#  ('收货行为_检测省份和收货省份不一致', 0.0),
#  ('百融按身份证号查询_近12个月申请其他的次数', 0.0)]

# %% [markdown]
# ### 验证

# %%
## 绘制ROC曲线并计算AUC的值
# fpr, tpr, threshold = roc_curve(y_train,clf.predict(x_train))
fpr, tpr, threshold = roc_curve(y_test,y_pred_proba)
roc_auc = auc(fpr,tpr)
plt.plot(fpr, tpr, color='darkorange',
          label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy',  linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC_curve')
plt.legend(loc="lower right")

# %%
threshold = []
recall,precision = [],[]
for t in np.arange(0.5,min(0.7,max(y_pred_proba)-0.001),0.01):
    y_pred = np.array([1 if x>=t else 0 for x in y_pred_proba])
    recall.append(len([y1 for y1,y2 in zip(y_test, y_pred) if y1==1 and y2==1])/len([x for x in y_test if x==1]))
    precision.append(len([y1 for y1,y2 in zip(y_test, y_pred) if y1==1 and y2==1])/len([x for x in y_pred if x==1]))
    threshold.append(t)

# %%
plt.plot(threshold, recall, color='darkorange', label='recall')
plt.plot(threshold, precision, color='navy', label='precision')
diff = list(abs(np.array(recall)-np.array(precision)))
best_threshold_3 = threshold[diff.index(min(diff))]
best_recall = recall[diff.index(min(diff))]
best_precision = precision[diff.index(min(diff))]
text = 'threshold='+str(round(best_threshold_3,2))+'\nrecall='+str(round(best_recall,2))+'\nprecision='+str(round(best_precision,2))
plt.xlim([0.5, 0.7])
plt.ylim([0.0, 0.5])
plt.xlabel('Threshold')
plt.ylabel('rate')
plt.title('CUT')
plt.legend(loc="lower right")
plt.annotate(text, xy=(best_threshold_3, best_recall), xytext=(best_threshold_3, best_recall+0.1))
# Out:
# Text(0.56, 0.3542372881355932, 'threshold=0.56\nrecall=0.25\nprecision=0.12')

# %% [markdown]
# ### 逾期率

# %%
sample_valid_predict = sample_valid.copy(deep=True)
sample_valid_predict['predict'] = [1 if x>=best_threshold_3 else 0 for x in clf.predict_proba(sample_valid[selected])[:,1]]
# sample_valid_predict['predict'] = [1 if x>=best_threshold_3 else 0 for x in clf.predict_proba(selected_onehot_df)[:,1]]

# %%
concentration(sample_valid)
# Out:
# 0.08987419942675365

# %%
sample_valid_predict.groupby('predict').apply(concentration)
# Out:
# predict
# 0    0.082571
# 1    0.125159
# dtype: float64

# %%
Counter(sample_valid_predict['predict'])
# Out:
# Counter({0: 10193, 1: 2178})

# %% [markdown]
# ### 画图

# %%
# import os
# os.environ["PATH"] += 'C:\\Users\\xx\\AppData\\Local\\Programs\\Python\\Python38\\Graphviz\\bin\\' + os.pathsep

# dot_data = tree.export_graphviz(clf, # 注意这个参数为决策树对象名称
#                                 out_file=None,
#                                 feature_names=selected, # 还需要指定特征名
#                                 class_names=target,
#                                 filled=True,
#                                 impurity=False,
#                                 rounded=True,
#                                 proportion=True,
#                                 rotate=True
#                                )

# graph = pydotplus.graph_from_dot_data(dot_data.replace('helvetica', 'MicrosoftYaHei'))
# # graph.get_nodes()[7].set_fillcolor("#FFF2DD")
# Image(graph.create_png())

# %%
viz = dtreeviz(clf, 
               x_data=x,
               y_data=y,
               target_name=target,
               feature_names=selected,
#                feature_names=selected_category_ftr,
               class_names={0:'未逾期',1:'逾期'}, 
               title="高风险套现新户",
               orientation='LR',
               fontname='SimHei',
               fancy=False,
#                X=x_test.loc[32598]
              )
viz

# %% [markdown]
# ## 随机森林

# %% [markdown]
# ### 训练

# %%
rf_classifier = RandomForestClassifier(n_estimators=10
                                       ,max_depth=3
                                       ,min_samples_leaf=70
                                       ,class_weight='balanced'
                                       ,random_state=0)
clf2 = rf_classifier.fit(x_train,y_train)
# 预测标签
y_pred_proba_train = clf2.predict_proba(x_train)[:,1]
y_pred_proba_test = clf2.predict_proba(x_test)[:,1]
y_pred_proba_all = clf2.predict_proba(x)[:,1]
print("测试集的平均正确率：{}".format(clf2.score(x_test,y_test)))

# # 计算回归值，取值小于0，表示p(y=1) <0.5,则该处标签属于1，否则属于0
# y_pred1 = clf.predict_proba(x_test)
# Out:
# 测试集的平均正确率：0.6540715296019398

# %%
sorted(list(zip(selected, rf_classifier.feature_importances_)), key=lambda x: x[1], reverse=True)
# Out:
# [('同盾近1800天查询次数', 0.32839846459841787),
#  ('年龄', 0.18080577807607096),
#  ('关联地址_收货地址610米内30天内注册新户数', 0.1518724164876105),
#  ('同盾近15天查询次数', 0.09046226656577329),
#  ('关联地址_3天内收货地址610米内被多个下单高套现风险新户使用', 0.07095784951466128),
#  ('百融按身份证号查询_近12个月申请其他的次数', 0.06724552061157535),
#  ('收货行为_检测省份和收货省份不一致', 0.05712098911311777),
#  ('百融按手机号查询_近6个月在非银机构最大月申请次数', 0.03562746470529294),
#  ('手机号码_30天内紧急联系人关联多人借款下单', 0.017509250327479943),
#  ('手机号码_90天内紧急联系人关联多人高风险套现下单', 0.0)]

# %% [markdown]
# ### 验证

# %% [markdown]
# ROC

# %%
## 绘制ROC曲线并计算AUC的值
# fpr, tpr, threshold = roc_curve(y_train,clf.predict(x_train))
fpr, tpr, threshold = roc_curve(y_train,y_pred_proba_train)
roc_auc = auc(fpr,tpr)
plt.plot(fpr, tpr, color='darkorange',
          label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy',  linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC_curve')
plt.legend(loc="lower right")

# %%
## 绘制ROC曲线并计算AUC的值
# fpr, tpr, threshold = roc_curve(y_train,clf.predict(x_train))
fpr, tpr, threshold = roc_curve(y_test,y_pred_proba_test)
roc_auc = auc(fpr,tpr)
plt.plot(fpr, tpr, color='darkorange',
          label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy',  linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC_curve')
plt.legend(loc="lower right")

# %% [markdown]
# precision,recall

# %%
threshold = []
recall,precision = [],[]
for t in np.arange(0.5,max(y_pred_proba_test)-0.001,0.01):
    y_pred = np.array([1 if x>=t else 0 for x in y_pred_proba_test])
    recall.append(len([y1 for y1,y2 in zip(y_test, y_pred) if y1==1 and y2==1])/len([x for x in y_test if x==1]))
    precision.append(len([y1 for y1,y2 in zip(y_test, y_pred) if y1==1 and y2==1])/len([x for x in y_pred if x==1]))
    threshold.append(t)

# %%
plt.plot(threshold, recall, color='darkorange', label='recall')
plt.plot(threshold, precision, color='navy', label='precision')
diff = list(abs(np.array(recall)-np.array(precision)))
best_threshold_4 = threshold[diff.index(min(diff))]
best_recall = recall[diff.index(min(diff))]
best_precision = precision[diff.index(min(diff))]
text = 'threshold='+str(round(best_threshold_4,2))+'\nrecall='+str(round(best_recall,2))+'\nprecision='+str(round(best_precision,2))
plt.xlim([0.5, 0.7])
plt.ylim([0.0, 1])
plt.xlabel('Threshold')
plt.ylabel('rate')
plt.title('CUT')
plt.legend(loc="lower right")
plt.annotate(text, xy=(best_threshold_4, best_recall), xytext=(best_threshold_4, best_recall+0.1))
# Out:
# Text(0.56, 0.24527845036319612, 'threshold=0.56\nrecall=0.15\nprecision=0.15')

# %% [markdown]
# KS

# %%
max(y_pred_proba_train*1000),max(y_pred_proba_test*1000)
# Out:
# (675.689400181014, 675.689400181014)

# %%
b = [-np.inf]+[i for i in np.arange(0.5,0.67,0.01)] +[np.inf]

# %%
y_pred_proba_train_bin = pd.cut(y_pred_proba_train, b)
y_df = pd.DataFrame({'特征': y_pred_proba_train_bin, 't': y_train}).reset_index(drop=True)
get_ks(y_df)
# Out:
#               分箱      个数    坏样本     好样本  累计badrate  累计goodrate    累计lift  \
# 0    (0.67, inf]     3.0    2.0     1.0   0.002999    0.000148  7.418291
# 1   (0.66, 0.67]     1.0    0.0     1.0   0.002999    0.000296  5.563718
# 2   (0.65, 0.66]     8.0    6.0     2.0   0.011994    0.000592  7.418291
# 3   (0.64, 0.65]    11.0    2.0     9.0   0.014993    0.001925  4.838016
# 4   (0.63, 0.64]    25.0    7.0    18.0   0.025487    0.004589  3.940967
# 5   (0.62, 0.63]    13.0    4.0     9.0   0.031484    0.005922  3.830757
# 6   (0.61, 0.62]    59.0   16.0    43.0   0.055472    0.012287  3.430960
# 7    (0.6, 0.61]    40.0    8.0    32.0   0.067466    0.017024  3.129591
# 8    (0.59, 0.6]    42.0    9.0    33.0   0.080960    0.021910  2.974661
# 9   (0.58, 0.59]    89.0   19.0    70.0   0.109445    0.032272  2.791419
# 10  (0.57, 0.58]   138.0   26.0   112.0   0.148426    0.048853  2.567870
# 11  (0.56, 0.57]   161.0   30.0   131.0   0.193403    0.068246  2.432948
# 12  (0.55, 0.56]   222.0   29.0   193.0   0.236882    0.096817  2.165191
# 13  (0.54, 0.55]   266.0   36.0   230.0   0.290855    0.130866  2.002526
# 14  (0.53, 0.54]   366.0   40.0   326.0   0.350825    0.179127  1.803200
# 15  (0.52, 0.53]   343.0   38.0   305.0   0.407796    0.224278  1.693712
# 16  (0.51, 0.52]   297.0   24.0   273.0   0.443778    0.264693  1.580480
# 17   (0.5, 0.51]   362.0   25.0   337.0   0.481259    0.314582  1.460305
# 18   (-inf, 0.5]  4976.0  346.0  4630.0   1.000000    1.000000  1.000000
#
#         KS分量        KS  badratio
# 0   0.002850  0.183518  0.666667
# 1   0.002702  0.183518  0.000000
# 2   0.011402  0.183518  0.750000
# 3   0.013068  0.183518  0.181818
# 4   0.020898  0.183518  0.280000
# 5   0.025563  0.183518  0.307692
# 6   0.043185  0.183518  0.271186
# 7   0.050442  0.183518  0.200000
# 8   0.059050  0.183518  0.214286
# 9   0.077173  0.183518  0.213483
# 10  0.099573  0.183518  0.188406
# 11  0.125158  0.183518  0.186335
# 12  0.140064  0.183518  0.130631
# 13  0.159989  0.183518  0.135338
# 14  0.171698  0.183518  0.109290
# 15  0.183518  0.183518  0.110787
# 16  0.179085  0.183518  0.080808
# 17  0.166678  0.183518  0.069061
# 18  0.000000  0.183518  0.069534

# %%
y_pred_proba_test_bin = pd.cut(y_pred_proba_test, b)
y_df = pd.DataFrame({'特征': y_pred_proba_test_bin, 't': y_test}).reset_index(drop=True)
get_ks(y_df)
# Out:
#               分箱      个数    坏样本     好样本  累计badrate  累计goodrate     累计lift  \
# 0    (0.67, inf]     2.0    2.0     0.0   0.004843    0.000000  11.983051
# 1   (0.65, 0.66]     5.0    3.0     2.0   0.012107    0.000441   8.559322
# 2   (0.64, 0.65]     2.0    1.0     1.0   0.014528    0.000661   7.988701
# 3   (0.63, 0.64]    18.0    0.0    18.0   0.014528    0.004630   2.662900
# 4   (0.62, 0.63]     5.0    1.0     4.0   0.016949    0.005511   2.621292
# 5   (0.61, 0.62]    41.0   11.0    30.0   0.043584    0.012125   2.954725
# 6    (0.6, 0.61]    33.0    3.0    30.0   0.050847    0.018739   2.374001
# 7    (0.59, 0.6]    21.0    4.0    17.0   0.060533    0.022487   2.358868
# 8   (0.58, 0.59]    60.0   12.0    48.0   0.089588    0.033069   2.370978
# 9   (0.57, 0.58]    90.0   14.0    76.0   0.123487    0.049824   2.206266
# 10  (0.56, 0.57]   113.0    9.0   104.0   0.145278    0.072751   1.843546
# 11  (0.55, 0.56]   150.0   25.0   125.0   0.205811    0.100309   1.886221
# 12  (0.54, 0.55]   185.0   24.0   161.0   0.263923    0.135802   1.801590
# 13  (0.53, 0.54]   251.0   21.0   230.0   0.314770    0.186508   1.596103
# 14  (0.52, 0.53]   265.0   29.0   236.0   0.384988    0.238536   1.535298
# 15  (0.51, 0.52]   183.0   10.0   173.0   0.409201    0.276675   1.422146
# 16   (0.5, 0.51]   253.0   20.0   233.0   0.457627    0.328042   1.350505
# 17   (-inf, 0.5]  3272.0  224.0  3048.0   1.000000    1.000000   1.000000
#
#         KS分量        KS  badratio
# 0   0.004843  0.146452  1.000000
# 1   0.011666  0.146452  0.600000
# 2   0.013866  0.146452  0.500000
# 3   0.009898  0.146452  0.000000
# 4   0.011438  0.146452  0.200000
# 5   0.031458  0.146452  0.268293
# 6   0.032108  0.146452  0.090909
# 7   0.038046  0.146452  0.190476
# 8   0.056520  0.146452  0.200000
# 9   0.073663  0.146452  0.155556
# 10  0.072527  0.146452  0.079646
# 11  0.105502  0.146452  0.166667
# 12  0.128120  0.146452  0.129730
# 13  0.128262  0.146452  0.083665
# 14  0.146452  0.146452  0.109434
# 15  0.132525  0.146452  0.054645
# 16  0.129585  0.146452  0.079051
# 17  0.000000  0.146452  0.068460

# %%
y_pred_proba_all_bin = pd.cut(y_pred_proba_all, b)
y_df = pd.DataFrame({'特征': y_pred_proba_all_bin, 't': y}).reset_index(drop=True)
get_ks(y_df)
# Out:
#               分箱      个数    坏样本     好样本  累计badrate  累计goodrate    累计lift  \
# 0    (0.67, inf]     5.0    4.0     1.0   0.003704    0.000089  9.163704
# 1   (0.66, 0.67]     1.0    0.0     1.0   0.003704    0.000177  7.636420
# 2   (0.65, 0.66]    13.0    9.0     4.0   0.012037    0.000531  7.837378
# 3   (0.64, 0.65]    13.0    3.0    10.0   0.014815    0.001417  5.727315
# 4   (0.63, 0.64]    43.0    7.0    36.0   0.021296    0.004605  3.512753
# 5   (0.62, 0.63]    18.0    5.0    13.0   0.025926    0.005757  3.448706
# 6   (0.61, 0.62]   100.0   27.0    73.0   0.050926    0.012222  3.264273
# 7    (0.6, 0.61]    73.0   11.0    62.0   0.061111    0.017713  2.842126
# 8    (0.59, 0.6]    63.0   13.0    50.0   0.073148    0.022142  2.750504
# 9   (0.58, 0.59]   149.0   31.0   118.0   0.101852    0.032592  2.636003
# 10  (0.57, 0.58]   228.0   40.0   188.0   0.138889    0.049243  2.433703
# 11  (0.56, 0.57]   274.0   39.0   235.0   0.175000    0.070056  2.209107
# 12  (0.55, 0.56]   372.0   54.0   318.0   0.225000    0.098220  2.058783
# 13  (0.54, 0.55]   451.0   60.0   391.0   0.280556    0.132849  1.924988
# 14  (0.53, 0.54]   617.0   61.0   556.0   0.337037    0.182092  1.722928
# 15  (0.52, 0.53]   608.0   67.0   541.0   0.399074    0.230006  1.630431
# 16  (0.51, 0.52]   480.0   34.0   446.0   0.430556    0.269507  1.518359
# 17   (0.5, 0.51]   615.0   45.0   570.0   0.472222    0.319989  1.416896
# 18   (-inf, 0.5]  8248.0  570.0  7678.0   1.000000    1.000000  1.000000
#
#         KS分量        KS  badratio
# 0   0.003615  0.169068  0.800000
# 1   0.003527  0.169068  0.000000
# 2   0.011506  0.169068  0.692308
# 3   0.013398  0.169068  0.230769
# 4   0.016691  0.169068  0.162791
# 5   0.020169  0.169068  0.277778
# 6   0.038704  0.169068  0.270000
# 7   0.043398  0.169068  0.150685
# 8   0.051007  0.169068  0.206349
# 9   0.069260  0.169068  0.208054
# 10  0.089646  0.169068  0.175439
# 11  0.104944  0.169068  0.142336
# 12  0.126780  0.169068  0.145161
# 13  0.147706  0.169068  0.133038
# 14  0.154945  0.169068  0.098865
# 15  0.169068  0.169068  0.110197
# 16  0.161049  0.169068  0.070833
# 17  0.152233  0.169068  0.073171
# 18  0.000000  0.169068  0.069108

# %%
b = [-np.inf]+[i for i in np.arange(0.5,0.67,0.02)] +[np.inf]

# %%
y_pred_proba_train_bin = pd.cut(y_pred_proba_train, b)
y_df = pd.DataFrame({'特征': y_pred_proba_train_bin, 't': y_train}).reset_index(drop=True)
get_ks(y_df)
# Out:
#              分箱      个数    坏样本     好样本  累计badrate  累计goodrate    累计lift  \
# 0   (0.66, inf]     4.0    2.0     2.0   0.002999    0.000296  5.563718
# 1  (0.64, 0.66]    19.0    8.0    11.0   0.014993    0.001925  4.838016
# 2  (0.62, 0.64]    38.0   11.0    27.0   0.031484    0.005922  3.830757
# 3   (0.6, 0.62]    99.0   24.0    75.0   0.067466    0.017024  3.129591
# 4   (0.58, 0.6]   131.0   28.0   103.0   0.109445    0.032272  2.791419
# 5  (0.56, 0.58]   299.0   56.0   243.0   0.193403    0.068246  2.432948
# 6  (0.54, 0.56]   488.0   65.0   423.0   0.290855    0.130866  2.002526
# 7  (0.52, 0.54]   709.0   78.0   631.0   0.407796    0.224278  1.693712
# 8   (0.5, 0.52]   659.0   49.0   610.0   0.481259    0.314582  1.460305
# 9   (-inf, 0.5]  4976.0  346.0  4630.0   1.000000    1.000000  1.000000
#
#        KS分量        KS  badratio
# 0  0.002702  0.183518  0.500000
# 1  0.013068  0.183518  0.421053
# 2  0.025563  0.183518  0.289474
# 3  0.050442  0.183518  0.242424
# 4  0.077173  0.183518  0.213740
# 5  0.125158  0.183518  0.187291
# 6  0.159989  0.183518  0.133197
# 7  0.183518  0.183518  0.110014
# 8  0.166678  0.183518  0.074355
# 9  0.000000  0.183518  0.069534

# %%
y_pred_proba_test_bin = pd.cut(y_pred_proba_test, b)
y_df = pd.DataFrame({'特征': y_pred_proba_test_bin, 't': y_test}).reset_index(drop=True)
get_ks(y_df)
# Out:
#              分箱      个数    坏样本     好样本  累计badrate  累计goodrate     累计lift  \
# 0   (0.66, inf]     2.0    2.0     0.0   0.004843    0.000000  11.983051
# 1  (0.64, 0.66]     7.0    4.0     3.0   0.014528    0.000661   7.988701
# 2  (0.62, 0.64]    23.0    1.0    22.0   0.016949    0.005511   2.621292
# 3   (0.6, 0.62]    74.0   14.0    60.0   0.050847    0.018739   2.374001
# 4   (0.58, 0.6]    81.0   16.0    65.0   0.089588    0.033069   2.370978
# 5  (0.56, 0.58]   203.0   23.0   180.0   0.145278    0.072751   1.843546
# 6  (0.54, 0.56]   335.0   49.0   286.0   0.263923    0.135802   1.801590
# 7  (0.52, 0.54]   516.0   50.0   466.0   0.384988    0.238536   1.535298
# 8   (0.5, 0.52]   436.0   30.0   406.0   0.457627    0.328042   1.350505
# 9   (-inf, 0.5]  3272.0  224.0  3048.0   1.000000    1.000000   1.000000
#
#        KS分量        KS  badratio
# 0  0.004843  0.146452  1.000000
# 1  0.013866  0.146452  0.571429
# 2  0.011438  0.146452  0.043478
# 3  0.032108  0.146452  0.189189
# 4  0.056520  0.146452  0.197531
# 5  0.072527  0.146452  0.113300
# 6  0.128120  0.146452  0.146269
# 7  0.146452  0.146452  0.096899
# 8  0.129585  0.146452  0.068807
# 9  0.000000  0.146452  0.068460

# %%
y_pred_proba_all_bin = pd.cut(y_pred_proba_all, b)
y_df = pd.DataFrame({'特征': y_pred_proba_all_bin, 't': y}).reset_index(drop=True)
get_ks(y_df)
# Out:
#              分箱      个数    坏样本     好样本  累计badrate  累计goodrate    累计lift  \
# 0   (0.66, inf]     6.0    4.0     2.0   0.003704    0.000177  7.636420
# 1  (0.64, 0.66]    26.0   12.0    14.0   0.014815    0.001417  5.727315
# 2  (0.62, 0.64]    61.0   12.0    49.0   0.025926    0.005757  3.448706
# 3   (0.6, 0.62]   173.0   38.0   135.0   0.061111    0.017713  2.842126
# 4   (0.58, 0.6]   212.0   44.0   168.0   0.101852    0.032592  2.636003
# 5  (0.56, 0.58]   502.0   79.0   423.0   0.175000    0.070056  2.209107
# 6  (0.54, 0.56]   823.0  114.0   709.0   0.280556    0.132849  1.924988
# 7  (0.52, 0.54]  1225.0  128.0  1097.0   0.399074    0.230006  1.630431
# 8   (0.5, 0.52]  1095.0   79.0  1016.0   0.472222    0.319989  1.416896
# 9   (-inf, 0.5]  8248.0  570.0  7678.0   1.000000    1.000000  1.000000
#
#        KS分量        KS  badratio
# 0  0.003527  0.169068  0.666667
# 1  0.013398  0.169068  0.461538
# 2  0.020169  0.169068  0.196721
# 3  0.043398  0.169068  0.219653
# 4  0.069260  0.169068  0.207547
# 5  0.104944  0.169068  0.157371
# 6  0.147706  0.169068  0.138518
# 7  0.169068  0.169068  0.104490
# 8  0.152233  0.169068  0.072146
# 9  0.000000  0.169068  0.069108

# %%
b = [-np.inf]+[i for i in np.arange(0.5,0.67,0.05)] +[np.inf]

# %%
y_pred_proba_train_bin = pd.cut(y_pred_proba_train, b)
y_df = pd.DataFrame({'特征': y_pred_proba_train_bin, 't': y_train}).reset_index(drop=True)
get_ks(y_df)
# Out:
#             分箱      个数    坏样本     好样本  累计badrate  累计goodrate    累计lift  \
# 0  (0.65, inf]    12.0    8.0     4.0   0.011994    0.000592  7.418291
# 1  (0.6, 0.65]   148.0   37.0   111.0   0.067466    0.017024  3.129591
# 2  (0.55, 0.6]   652.0  113.0   539.0   0.236882    0.096817  2.165191
# 3  (0.5, 0.55]  1634.0  163.0  1471.0   0.481259    0.314582  1.460305
# 4  (-inf, 0.5]  4976.0  346.0  4630.0   1.000000    1.000000  1.000000
#
#        KS分量        KS  badratio
# 0  0.011402  0.166678  0.666667
# 1  0.050442  0.166678  0.250000
# 2  0.140064  0.166678  0.173313
# 3  0.166678  0.166678  0.099755
# 4  0.000000  0.166678  0.069534

# %%
y_pred_proba_test_bin = pd.cut(y_pred_proba_test, b)
y_df = pd.DataFrame({'特征': y_pred_proba_test_bin, 't': y_test}).reset_index(drop=True)
get_ks(y_df)
# Out:
#             分箱      个数    坏样本     好样本  累计badrate  累计goodrate    累计lift  \
# 0  (0.65, inf]     7.0    5.0     2.0   0.012107    0.000441  8.559322
# 1  (0.6, 0.65]    99.0   16.0    83.0   0.050847    0.018739  2.374001
# 2  (0.55, 0.6]   434.0   64.0   370.0   0.205811    0.100309  1.886221
# 3  (0.5, 0.55]  1137.0  104.0  1033.0   0.457627    0.328042  1.350505
# 4  (-inf, 0.5]  3272.0  224.0  3048.0   1.000000    1.000000  1.000000
#
#        KS分量        KS  badratio
# 0  0.011666  0.129585  0.714286
# 1  0.032108  0.129585  0.161616
# 2  0.105502  0.129585  0.147465
# 3  0.129585  0.129585  0.091469
# 4  0.000000  0.129585  0.068460

# %%
y_pred_proba_all_bin = pd.cut(y_pred_proba_all, b)
y_df = pd.DataFrame({'特征': y_pred_proba_all_bin, 't': y}).reset_index(drop=True)
get_ks(y_df)
# Out:
#             分箱      个数    坏样本     好样本  累计badrate  累计goodrate    累计lift  \
# 0  (0.65, inf]    19.0   13.0     6.0   0.012037    0.000531  7.837378
# 1  (0.6, 0.65]   247.0   53.0   194.0   0.061111    0.017713  2.842126
# 2  (0.55, 0.6]  1086.0  177.0   909.0   0.225000    0.098220  2.058783
# 3  (0.5, 0.55]  2771.0  267.0  2504.0   0.472222    0.319989  1.416896
# 4  (-inf, 0.5]  8248.0  570.0  7678.0   1.000000    1.000000  1.000000
#
#        KS分量        KS  badratio
# 0  0.011506  0.152233  0.684211
# 1  0.043398  0.152233  0.214575
# 2  0.126780  0.152233  0.162983
# 3  0.152233  0.152233  0.096355
# 4  0.000000  0.152233  0.069108

# %% [markdown]
# ### 逾期率

# %%
sample_valid_predict = sample_valid.copy(deep=True)
# sample_valid_predict['predict'] = [1 if x>=best_threshold_4 else 0 for x in clf2.predict_proba(sample_valid[selected])[:,1]]
sample_valid_predict['predict'] = [1 if x>=0.65 else 0 for x in clf2.predict_proba(sample_valid_predict[selected])[:,1]]
# sample_valid_predict['predict'] = [1 if x>=best_threshold_4 else 0 for x in clf2.predict_proba(selected_onehot_df)[:,1]]
# sample_valid_predict['predict'] = [1 if x>=0.63 else 0 for x in clf2.predict_proba(selected_onehot_df)[:,1]]

# %%
concentration(sample_valid)
# Out:
# 0.08987419942675365

# %%
sample_valid_predict.groupby('predict').apply(concentration)
# Out:
# predict
# 0    0.089147
# 1    0.693545
# dtype: float64

# %%
Counter(sample_valid_predict['predict'])
# Out:
# Counter({0: 12352, 1: 19})

# %%
x_train.shape[0], x_test.shape[0]
# Out:
# (7422, 4949)

# %% [markdown]
# ### 画图

# %%
# import os
# os.environ["PATH"] += 'C:\\Users\\xx\\AppData\\Local\\Programs\\Python\\Python38\\Graphviz\\bin\\' + os.pathsep

# # 随机森林画图
# i=0
# for per_rf in rf_classifier.estimators_:
#     dot_data = tree.export_graphviz(per_rf,
#                                     out_file=None,
#                                     feature_names=selected, # 还需要指定特征名
#                                     class_names=target,
#                                     filled=True,
#                                     impurity=False,
#                                     rounded=True,
#                                     proportion=True,
#                                     rotate=True
#                                    )
#     graph = pydotplus.graph_from_dot_data(dot_data.replace('helvetica', 'MicrosoftYaHei'))
#     # graph.get_nodes()[7].set_fillcolor("#FFF2DD")
# #     Image(graph.create_png())
#     graph.write_pdf("./output/"+str(i)+"DTtree.pdf")
# #     break
#     i = i+1

# %%
# 随机森林画图
i=0
for per_rf in rf_classifier.estimators_:
    viz = dtreeviz(per_rf, 
                   x_data=x,
                   y_data=y,
                   target_name=target,
                   feature_names=selected,
#                    feature_names=selected_category_ftr, 
                   class_names={0:'未逾期',1:'逾期'}, 
                   title="高风险套现新户",
                   orientation='LR',
                   fontname='SimHei',
                   fancy=False,
    #                X=x_test.loc[32598]
                  )
    viz.save("./output/"+str(i)+"DTtree.svg")
    viz.view()
    i = i+1

# %% [markdown]
# # 单观察点

# %%
repayinfo[repayinfo['注册手机']==18502675260][['注册手机','下单时间','品类','收货地址']+selected].reset_index(drop=True)
# Out:
#           注册手机        下单时间     品类                     收货地址  \
# 0  18502675260  2022-06-14  高风险套现  四川省 成都市 龙泉驿区 第九空间大厦1812
# 1  18502675260  2022-06-13  高风险套现  四川省 成都市 龙泉驿区 第九空间大厦1812
# 2  18502675260  2022-06-17  高风险套现  四川省 成都市 龙泉驿区 第九空间大厦1812
# 3  18502675260  2022-06-14  高风险套现  四川省 成都市 龙泉驿区 第九空间大厦1812
# 4  18502675260  2022-06-14  高风险套现  四川省 成都市 龙泉驿区 第九空间大厦1812
#
#    关联地址_3天内收货地址610米内被多个下单高套现风险新户使用  关联地址_收货地址610米内30天内注册新户数  同盾近15天查询次数  \
# 0                                9                       30           5
# 1                               14                       30           5
# 2                               11                       30           5
# 3                                9                       30           5
# 4                                9                       30           5
#
#    同盾近1800天查询次数  年龄  手机号码_30天内紧急联系人关联多人借款下单  手机号码_90天内紧急联系人关联多人高风险套现下单  \
# 0            67  41                       0                          1
# 1            67  41                       0                          1
# 2            67  41                       0                          1
# 3            67  41                       0                          1
# 4            67  41                       0                          1
#
#    收货行为_检测省份和收货省份不一致  百融按手机号查询_近6个月在非银机构最大月申请次数  百融按身份证号查询_近12个月申请其他的次数
# 0                  1                         10                       5
# 1                  0                         10                       5
# 2                  1                         10                       5
# 3                  1                         10                       5
# 4                  1                         10                       5

# %%
tmp_fp_df = repayinfo[repayinfo['注册手机']==18502675260][selected].reset_index(drop=True)
tmp_fp_df
# Out:
#    关联地址_3天内收货地址610米内被多个下单高套现风险新户使用  关联地址_收货地址610米内30天内注册新户数  同盾近15天查询次数  \
# 0                                9                       30           5
# 1                               14                       30           5
# 2                               11                       30           5
# 3                                9                       30           5
# 4                                9                       30           5
#
#    同盾近1800天查询次数  年龄  手机号码_30天内紧急联系人关联多人借款下单  手机号码_90天内紧急联系人关联多人高风险套现下单  \
# 0            67  41                       0                          1
# 1            67  41                       0                          1
# 2            67  41                       0                          1
# 3            67  41                       0                          1
# 4            67  41                       0                          1
#
#    收货行为_检测省份和收货省份不一致  百融按手机号查询_近6个月在非银机构最大月申请次数  百融按身份证号查询_近12个月申请其他的次数
# 0                  1                         10                       5
# 1                  0                         10                       5
# 2                  1                         10                       5
# 3                  1                         10                       5
# 4                  1                         10                       5

# %%
clf2.predict_proba(tmp_fp_df.loc[[0],:])[0][-1]
# Out:
# 0.5674913811981818

# %%
for per_rf in rf_classifier.estimators_:
    ep = explain_prediction_path(per_rf, x=tmp_fp_df.loc[0], feature_names=selected, explanation_type="plain_english")
    pp = per_rf.predict_proba(tmp_fp_df.loc[[0],:])[0][-1]
    if pp>=best_threshold_4:
        print(str(pp)+'\n'+ep)
# Out:
# 0.7787050027976077
# 40.5 <= 年龄
# 0.5 <= 收货行为_检测省份和收货省份不一致
#
# 0.7466518485172474
# 4.5 <= 关联地址_收货地址610米内30天内注册新户数
# 4.5 <= 同盾近15天查询次数
# 33.5 <= 年龄
#
# 0.6658404269076231
# 2.5 <= 关联地址_收货地址610米内30天内注册新户数
# 3.5 <= 百融按身份证号查询_近12个月申请其他的次数
#
# 0.7015826855321294
# 2.5 <= 关联地址_收货地址610米内30天内注册新户数
# 65.5 <= 同盾近1800天查询次数
# 1.5 <= 百融按身份证号查询_近12个月申请其他的次数
#
# 0.5975988410740443
# 1.5 <= 关联地址_3天内收货地址610米内被多个下单高套现风险新户使用
# 24.5 <= 年龄
# 0.5 <= 收货行为_检测省份和收货省份不一致
#
# 0.5627565557947302
# 1.5 <= 关联地址_收货地址610米内30天内注册新户数
# 同盾近15天查询次数 < 13.5
# 25.5 <= 年龄

# %%
tmp_fp_df2 = repayinfo[repayinfo['注册手机']==18502675260][selected+[target]+['fpd15amo','fpd15amosum']].reset_index(drop=True)

# %%
tmp_fp_df_cut = tmp_fp_df2.copy(deep=True)
for s in selected:
    tmp_fp_df_cut[s+'_cut'] = pd.cut(tmp_fp_df_cut[s], [-np.inf, float(sift_df[sift_df['特征']==s]['maxliftcut']), np.inf])

# %%
classify(tmp_fp_df2.loc[0], tree1, p=1)
# Out:
# 手机号码_90天内紧急联系人关联多人高风险套现下单 >= 1
# 同盾近15天查询次数 < 17
# 年龄 >= 41
# {1.0: 61, 0.0: 379, 'con': 0.1486}

# %%
classify(tmp_fp_df_cut.loc[0], tree2, p=1)
# Out:
# 关联地址_3天内收货地址610米内被多个下单高套现风险新户使用_cut 不等于 (1.0, inf]
# 同盾近1800天查询次数_cut 不等于 (74.0, inf]
# 年龄_cut 不等于 (-inf, 29.0]
# {0.0: 1508, 1.0: 178, 'con': 0.1133}

# %% [markdown]
# # 模型保存

# %%
# joblib.dump(clf2, './output/rf_20220802.model')
# Out:
# ['./output/rf_20220802.model']

# %%
# from odps import ODPS
# from odps.df import DataFrame

# o = ODPS('LTAI4G4xSRz19v5d2UPmGvB2', 'RZt7RaVAPgC0eEQtvIzD622PCnTh25', project='basestone_rs_dev')
# # order_history_table = DataFrame(o.get_table('order_history_table_shl')).to_pandas()

# def read_sql_query(odps, sql):
#     """
#     :param odps:
#     :param sql:
#     :return: pandas DataFrame
#     """
#     try:
#         readers_ = odps.execute_sql(sql).open_reader()
#         col_name = [i.name for i in readers_.schema]
 
#         data = pd.concat([pd.DataFrame({column: [value] for column, value in zip(col_name, reader.values)}) for reader in readers_])
#     except Exception as e:
#         data = pd.DataFrame({'info':[e]})
#         print(e)
#     finally:
#         return data

# tmp_repayinfo_shl2 = read_sql_query(odps=o, sql= """
# select a.订单号
# , b.fpd3_ind as oot_fpd3_ind
# , b.fpd7_ind as oot_fpd7_ind
# , b.fpd15_ind as oot_fpd15_ind
# from tmp_fraud_shl a
# left join (select * from bt_order_loan_back_info where dt=0000) b
# on a.订单号=b.order_code
# where a.fd3_ind=0 and b.fd3_ind=1
# """
# )

# sample_valid2 = pd.merge(left=tmp_repayinfo_shl2, right=repayinfo, how='left', on='订单号')
